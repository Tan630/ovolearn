# %%
import os
import sys
nb_dir = os.path.split(os.getcwd())[0]
if nb_dir not in sys.path:
    sys.path.append(nb_dir)

# %% [markdown]
# Import

# %%
from core.controller import Controller
from core.population import Population
from core.selector import Elitist, TournamentSelector
from core.selector import Elitist, TournamentSelector
from evolvables.planewalker import Position, FunctionEvaluator, StepMutator

# %% [markdown]
# Create population

# %%
def himmelblau(x:float, y:float):
    return (x**2 + y - 11)**2 + (x + y**2 - 7)**2


init_pop = Population[Position]()


for i in range (100):
    init_pop.append(Position.create_random(((-5,5), (-5,5))))



evaluator = FunctionEvaluator(himmelblau)
selector = Elitist(TournamentSelector[Position](1, 10))
variator = StepMutator(3)

ctrl = Controller[Position](
    population = init_pop,
    evaluator = evaluator,
    variator = variator,
    survivor_selector = selector,
    parent_selector = selector
)

dicts = {}
for i in range(0, 1000):
    ctrl.step()
    dicts[i] = ctrl.population[0].score

print (dicts)
# Out:
# parent pool size:100
# 50
# ppppppp length: 50
# survivor pool size:101
# generation done, best:div ( sin ( cos ( mul ( lim ( sym_1 () sym_3 () sym_2 ()) cos ( sym_3 ())))) sym_3 ()) with score -7.5563435855071095, re-evaluate: -4.032903883878151
# parent pool size:101
# 51
# ppppppp length: 51
# survivor pool size:101
# generation done, best:sin ( div ( sym_1 () lim ( sin ( sym_1 ()) lim ( sym_1 () sym_3 () sym_3 ()) cos ( sym_3 ())))) with score -4.654132782892806, re-evaluate: -5.683927893598097
# parent pool size:101
# 51
# ppppppp length: 51
# survivor pool size:101
# generation done, best:sin ( div ( sym_1 () lim ( sin ( sym_1 ()) lim ( sym_1 () sym_3 () sym_3 ()) cos ( sym_3 ())))) with score -4.654132782892806, re-evaluate: -6.082883607857674
# parent pool size:101
# 51
# ppppppp length: 51
# survivor pool size:101
# generation done, best:sin ( div ( sym_1 () lim ( sin ( sym_1 ()) lim ( sym_1 () sym_3 () sym_3 ()) cos ( sym_3 ())))) with score -4.654132782892806, re-evaluate: -6.87890990114648
# parent pool size:101
# 51
# ppppppp length: 51
# survivor pool size:101
# generation done, best:sin ( div ( sym_1 () lim ( sin ( sym_1 ()) lim ( sym_1 () sym_3 () sym_3 ()) cos ( sym_3 ())))) with score -4.654132782892806, re-evaluate: -5.713258015534591
# parent pool size:101
# 51
# ppppppp length: 51
# survivor pool size:101
# generation done, best:sin ( div ( sym_1 () lim ( sin ( sym_1 ()) lim ( sym_1 () sym_3 () sym_3 ()) cos ( sym_3 ())))) with score -4.654132782892806, re-evaluate: -4.446352451725962
# parent pool size:101
# 51
# ppppppp length: 51
# survivor pool size:101
# generation done, best:sin ( div ( sym_1 () lim ( sin ( sym_1 ()) lim ( sym_1 () sym_3 () sym_3 ()) cos ( sym_3 ())))) with score -4.654132782892806, re-evaluate: -6.309188274563891
# parent pool size:101
# 51
# ppppppp length: 51
# survivor pool size:101
# generation done, best:sin ( div ( sym_1 () lim ( sin ( sym_1 ()) lim ( sym_1 () sym_3 () sym_3 ()) cos ( sym_3 ())))) with score -4.654132782892806, re-evaluate: -3.84441998578927
# parent pool size:101
# 51
# ppppppp length: 51
# survivor pool size:101
# generation done, best:sin ( div ( sym_1 () lim ( sin ( sym_1 ()) lim ( sym_1 () sym_3 () sym_3 ()) cos ( sym_3 ())))) with score -4.654132782892806, re-evaluate: -3.363250822374126
# parent pool size:101
# 51
# ppppppp length: 51
# survivor pool size:101
# generation done, best:sin ( div ( sym_1 () lim ( sin ( sym_1 ()) lim ( sym_1 () sym_3 () sym_3 ()) cos ( sym_3 ())))) with score -4.654132782892806, re-evaluate: -3.330985698728534
# parent pool size:101
# 51
# ppppppp length: 51
# survivor pool size:101
# generation done, best:sin ( div ( sym_1 () lim ( sin ( sym_1 ()) lim ( sym_1 () sym_3 () sym_3 ()) cos ( sym_3 ())))) with score -4.654132782892806, re-evaluate: -6.512218922281773
# parent pool size:101
# 51
# ppppppp length: 51
# survivor pool size:101
# generation done, best:lim ( lim ( lim ( sin ( sym_3 ()) sub ( sym_1 () sym_2 ()) add ( sym_3 () sym_2 ())) sym_1 () sym_3 ()) div ( div ( sin ( sym_2 ()) lim ( sym_2 () sym_2 () sym_3 ())) sin ( div ( sym_3 () div ( sym_2 () sym_1 ())))) sym_1 ()) with score -3.700512585158028, re-evaluate: -4.163779202868961
# parent pool size:101
# 51
# ppppppp length: 51
# survivor pool size:101
# generation done, best:lim ( lim ( lim ( sin ( sym_3 ()) sub ( sym_1 () sym_2 ()) add ( sym_3 () sym_2 ())) sym_1 () sym_3 ()) div ( div ( sin ( sym_2 ()) lim ( sym_2 () sym_2 () sym_3 ())) sin ( div ( sym_3 () div ( sym_2 () sym_1 ())))) sym_1 ()) with score -3.700512585158028, re-evaluate: -4.692816461542586
# parent pool size:101
# 51
# ppppppp length: 51
# survivor pool size:101
# generation done, best:lim ( lim ( lim ( sin ( sym_3 ()) sub ( sym_1 () sym_2 ()) add ( sym_3 () sym_2 ())) sym_1 () sym_3 ()) div ( div ( sin ( sym_2 ()) lim ( sym_2 () sym_2 () sym_3 ())) sin ( div ( sym_3 () div ( sym_2 () sym_1 ())))) sym_1 ()) with score -3.700512585158028, re-evaluate: -3.3361021868629344
# parent pool size:101
# 51
# ppppppp length: 51
# survivor pool size:101
# generation done, best:lim ( lim ( lim ( sin ( sym_3 ()) sub ( sym_1 () sym_2 ()) add ( sym_3 () sym_2 ())) sym_1 () sym_3 ()) div ( div ( sin ( sym_2 ()) lim ( sym_2 () sym_2 () sym_3 ())) sin ( div ( sym_3 () div ( sym_2 () sym_1 ())))) sym_1 ()) with score -3.700512585158028, re-evaluate: -4.46346079077522
# parent pool size:101
# 51
# ppppppp length: 51
# survivor pool size:101
# generation done, best:lim ( lim ( lim ( sin ( sym_3 ()) sub ( sym_1 () sym_2 ()) add ( sym_3 () sym_2 ())) sym_1 () sym_3 ()) div ( div ( sin ( sym_2 ()) lim ( sym_2 () sym_2 () sym_3 ())) sin ( div ( sym_3 () div ( sym_2 () sym_1 ())))) sym_1 ()) with score -3.700512585158028, re-evaluate: -4.102999229864976
# parent pool size:101
# 51
# ppppppp length: 51
# survivor pool size:101
# generation done, best:sub ( sin ( lim ( sym_1 () cos ( sym_3 ()) lim ( sym_2 () sym_3 () sym_1 ()))) mul ( cos ( lim ( sym_1 () sym_1 () sym_2 ())) sin ( div ( sin ( sym_2 ()) lim ( sym_3 () sym_2 () sym_3 ()))))) with score -3.3532027806271385, re-evaluate: -5.155922233266831
# parent pool size:101
# 51
# ppppppp length: 51
# survivor pool size:101
# generation done, best:sub ( sin ( lim ( sym_1 () cos ( sym_3 ()) lim ( sym_2 () sym_3 () sym_1 ()))) mul ( cos ( lim ( sym_1 () sym_1 () sym_2 ())) sin ( div ( sin ( sym_2 ()) lim ( sym_3 () sym_2 () sym_3 ()))))) with score -3.3532027806271385, re-evaluate: -4.131064265760722
# parent pool size:101
# 51
# ppppppp length: 51
# survivor pool size:101
# generation done, best:sub ( sin ( lim ( sym_1 () cos ( sym_3 ()) lim ( sym_2 () sym_3 () sym_1 ()))) mul ( cos ( lim ( sym_1 () sym_1 () sym_2 ())) sin ( div ( sin ( sym_2 ()) lim ( sym_3 () sym_2 () sym_3 ()))))) with score -3.3532027806271385, re-evaluate: -3.7174775608420694
# parent pool size:101
# 51
# ppppppp length: 51
# survivor pool size:101
# generation done, best:sub ( sin ( lim ( sym_1 () cos ( sym_3 ()) lim ( sym_2 () sym_3 () sym_1 ()))) mul ( cos ( lim ( sym_1 () sym_1 () sym_2 ())) sin ( div ( sin ( sym_2 ()) lim ( sym_3 () sym_2 () sym_3 ()))))) with score -3.3532027806271385, re-evaluate: -3.8365713029220685

# %% [markdown]
# Plot everything

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as colors

# %%
X = np.arange(-5, 5, 0.1)
Y = np.arange(-5, 5, 0.1)
X, Y = np.meshgrid(X, Y)
Z = himmelblau(X, Y)
#Z = rosenbrock(X, Y)

fig = plt.figure(figsize=(8, 6))
cs = plt.contour(X, Y, Z, levels=100, cmap='Spectral',
                 norm=colors.Normalize(vmin=Z.min(), vmax=Z.max()), alpha=0.4)
fig.colorbar(cs)


lists = [x.pos for x in ctrl.population]
xs = [x[0] for x in lists]
ys = [x[1] for x in lists]
plt.scatter(xs, ys)
plt.show()


plt.show()
