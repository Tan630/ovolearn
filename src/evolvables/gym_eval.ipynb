# %%
import os
import sys
nb_dir = os.path.split(os.getcwd())[0]
if nb_dir not in sys.path:
    sys.path.append(nb_dir)

# %%
from __future__ import annotations
import abc
import typing
import math
import functools

from typing import Optional
from typing import Tuple
from typing import Dict
from typing import Generic
from typing import Type
from dataclasses import dataclass

from typing import Union
from typing import List
from typing import Any
from typing import Self
from typing import Callable
from inspect import signature

from core.globals import LogLevel
from core.globals import report
from core.variator import Variator
from core.selector import ElitistSimpleSelector, SimpleSelector
from core.selector import Elitist
from core.selector import TournamentSelector
from core.evaluator import Evaluator
from core.controller import Controller
from core.population import Population
from core.population import Genome
from evolvables.expression import Program
from evolvables.expression import ProgramCrossoverVariator

from evolvables.expression import ProgramFactory


import random



import gymnasium as gym

from random import choice

# %%
def neg(x):
    return -x

def add(x, y):
    return x+y

def sub(x, y):
    return x-y

def mul(x, y):
    return x*y

def div(x, y):
    return 0 if y==0 else x/y

def log(x):
    abs_x = abs(x)
    return 0 if (abs_x == 0) else math.log(abs(x))

def lim(x, a, b):
    return min(max(min(a,b), x), max(a,b))

def avg(x, y):
    return (x+y)/2

def val0():
    return 0

def val1():
    return 1

def protectedDiv(left, right):
    try: return truncate(left, 8) / truncate(right, 8)
    except ZeroDivisionError: return 0
    
def if_then_else(input, output1, output2):
    if input: return output1
    else: return output2

def limit(input, minimum, maximum):
    return min(max(input,minimum), maximum)

# helper function to limit decimal places
def truncate(number, decimals=0):
    if not isinstance(decimals, int):
        raise TypeError("decimal places must be an integer.")
    elif decimals < 0:
        raise ValueError("decimal places has to be 0 or more.")
    elif decimals == 0:
        return math.trunc(number)
    factor = 10.0 ** decimals
    return math.trunc(number * factor) / factor

# %%
class GymEvaluator(Evaluator[Program[float]]):
    def __init__(self, env, wrapper: Callable[[float], float], episode_count: int, step_count: int, score_wrapper: Callable[[float], float] = lambda x : x):
        super().__init__()
        self.env = env
        self.wrapper = wrapper
        self.episode_count = episode_count
        self.step_count = step_count
        self.score_wrapper = score_wrapper

    def evaluate(self, s1: Program[float]) -> float:
        score = self.evaluate_episode(s1, self.env, self.wrapper, self.episode_count, self.step_count)
        # score = s1.evaluate(1,4,8,16)
        
        #score = GymEvaluator.evaluate_episode(s1, self.env, self.wrapper, self.episode_count, self.step_count) 
        return self.score_wrapper(score)

    @staticmethod
    def evaluate_episode(s1: Program[float], env, wrapper: Callable[[float], float], episode_count: int, step_count: int) -> float:
        score = 0.
        
        for i in range(0, episode_count):
            score = score + GymEvaluator.evaluate_step(s1, env, wrapper, step_count)
        return score / episode_count

    @staticmethod
    def evaluate_step(s1: Program[float], env, wrapper: Callable[[float], float], step_count: int) -> float:
        
        step_result = env.reset()
        score = 0.
        # hard coded - an episode consists of 10 evaluations.
        for i in range(0, step_count):
            if (len(step_result)>=5 and (step_result[2] or step_result[3])):
                break
            step_result = env.step(wrapper(s1.evaluate(*step_result[0]))) #type: ignore
            if (step_result[2]):
                break
            score = score + step_result[1] #type: ignore
        return score


# ########## Begin setup :) ########## #

# Size of the population. Affects the size of the initial initial population, also enforced by selectors.
pop_size = 100

# Depth constraint of the expression tree
tree_depth = 5
# Node budget of the expression tree
node_budget = 20

# The number of episodes for each evaluation. The actual score should be the mean of these scores.
# The length of each episode is hard-coded to be 10 (see `evaluate_step`)
step_bound = 10
episode_bound = 25


# Build the population of ternary programs. The arity (4) should match the size of the observation space (4 for cartpole)
progf = ProgramFactory((add, sub, mul, div, math.sin, lim), 4)

# Declare and populate the population
pops: Population[Program[float]] = Population()
for i in range(0, pop_size):
    pops.append(progf.build(tree_depth, node_budget))

# Prepare the variator
variator = ProgramCrossoverVariator(arity = 2, coarity = 3)

# The evaluaor is ready. Feed the custom wrapper and the environment to GymEvaluator
def pendulum_wrapper(f: float):
    return [round(max(min(2, f), -2))]

def cartpole_wrapper(f: float) -> int:
    result = round(max(min(1, f), 0))
    return result

eval = gym.make('CartPole-v1')
evaluator = GymEvaluator(eval, cartpole_wrapper, step_bound, episode_bound, score_wrapper = lambda x : x)

# Prepare the selector.
import gymnasium as gym
selp = SimpleSelector[Program[float]](coarity = 2, budget = pop_size)
selc = Elitist(TournamentSelector[Program[float]](coarity = 2, budget = pop_size))

ctrl = Controller[Program[float]](
    population = pops,
    evaluator = evaluator,
    parent_selector = selc,
    variator = variator,
    survivor_selector = selp
)

best_solutions: List[Program] = []
best_scores: List[Program] = []

def score_keeper(best_scores, best_solutions, c: Controller[Program[T]]):
    best_solutions = best_solutions.append(c.population[0])
    best_scores = best_scores.append(c.population[0].score)

from functools import partial
for i in range(0, 20):
    ctrl.step(partial(score_keeper, best_scores, best_solutions))


print ([str(x) for x in best_solutions])
print (str(best_scores))
# Out:
# sin(lim(sym_1, sym_2, sub(sym_1, lim(mul(sym_2, sym_2), sub(sym_3, sym_2), lim(sym_4, sym_4, sym_4)))))-----add(sin(lim(sym_3, sym_4, sub(lim(sym_1, sym_3, sym_1), lim(sym_2, sym_2, sym_3)))), lim(sym_3, sub(lim(sym_4, lim(sym_3, sym_4, sym_1), sin(sym_2)), sin(sin(sym_2))), sym_2))
# sym_4-----sin(sin(div(div(mul(sym_1, sym_4), sub(sym_4, sym_1)), add(lim(sym_4, sym_1, sym_3), add(sym_2, sym_1)))))
# lim(lim(sin(sym_1), lim(lim(lim(sym_4, sym_4, sym_2), sub(sym_3, sym_1), sym_4), sym_4, sym_3), add(sin(sub(sym_4, sym_2)), sym_4)), sub(lim(sym_4, sin(lim(sym_1, sym_1, sym_2)), sin(sym_4)), sym_2), sin(sin(sym_4)))-----div(div(sin(lim(lim(sym_3, sym_1, sym_3), sin(sym_2), sym_1)), sin(add(lim(sym_1, sym_2, sym_3), mul(sym_1, sym_2)))), sin(sym_2))
# div(lim(lim(sin(add(sym_3, sub(sym_4, sym_2))), sub(sin(mul(sym_3, sym_1)), sym_3), lim(sym_4, lim(mul(sym_3, sym_2), sin(sym_3), sin(sym_3)), sym_3)), sym_2, sym_4), sin(lim(sym_2, sym_4, sym_3)))-----lim(lim(sin(sin(sym_2)), lim(sym_4, div(sym_1, sym_1), sym_3), sym_3), sin(sin(sym_1)), add(mul(sym_4, lim(sym_2, sym_4, sym_4)), add(sym_2, lim(sym_2, sym_3, sym_1))))
# sub(div(sin(mul(lim(sym_4, sym_3, sym_4), div(sym_2, sym_3))), lim(sub(sym_1, sub(sym_2, sym_4)), lim(sym_2, sym_1, sym_3), sym_1)), sym_3)-----add(sub(lim(div(sym_3, lim(sym_1, sym_1, sym_2)), sym_1, sin(sin(sym_3))), mul(lim(sym_4, lim(sym_4, sym_2, sym_3), sym_1), sym_4)), lim(sym_4, sin(add(sym_4, sym_3)), sym_4))
# lim(sym_4, sub(add(sym_4, mul(sin(sym_4), lim(sym_1, sym_4, sym_1))), sym_2), mul(sin(sym_2), lim(sym_4, lim(sin(sym_3), sym_3, sym_4), sub(lim(sym_1, sym_1, sym_2), sym_1))))-----sin(lim(sin(add(sym_2, sym_3)), div(lim(sym_2, add(sym_3, sym_2), lim(sym_4, sym_3, sym_2)), sub(sym_3, mul(sym_3, sym_2))), div(sym_4, sym_4)))
# mul(sin(sin(sub(sym_1, lim(sym_2, sym_2, sym_1)))), sin(sin(lim(sym_3, sin(sym_2), lim(sym_2, sym_4, sym_3)))))-----div(sub(sub(add(lim(sym_2, sym_4, sym_4), mul(sym_2, sym_1)), lim(sym_1, sin(sym_4), sin(sym_4))), lim(lim(lim(sym_3, sym_2, sym_2), lim(sym_4, sym_4, sym_4), sym_2), sym_3, sym_2)), add(sym_1, lim(sym_3, sin(sym_3), sym_3)))
# lim(sym_4, lim(sym_1, sym_2, sin(sin(sym_2))), sin(sub(sin(sin(lim(sym_4, sym_1, sym_2))), sym_2)))-----sin(sin(lim(sym_3, mul(sym_1, sym_3), lim(sym_2, sym_4, sym_2))))
# sym_1-----add(add(sub(sym_2, lim(sin(sym_1), sin(sym_4), lim(sym_3, sym_2, sym_4))), sin(sym_4)), sym_4)
# div(div(lim(lim(sym_4, sym_4, sym_4), sym_2, sym_4), lim(sub(sym_1, sym_1), div(sym_2, sym_1), lim(sym_4, sym_3, sym_1))), div(div(add(sym_4, lim(sym_3, sym_1, sym_4)), sym_2), mul(add(div(sym_2, sym_3), sub(sym_1, sym_2)), sub(sym_2, sym_1))))-----lim(sym_4, sym_3, lim(sin(lim(sub(lim(sym_1, sym_3, sym_1), sub(sym_2, sym_2)), sin(add(sym_4, sym_3)), sym_2)), mul(sin(lim(sym_3, sym_2, sym_2)), sub(sym_3, div(sym_1, sym_4))), sym_2))
# sin(sin(lim(sym_4, sin(lim(sym_3, sym_3, sym_3)), sin(sym_2))))-----sub(sym_4, add(lim(lim(lim(sym_2, sym_1, sym_1), add(sym_3, sym_4), sym_1), lim(sin(sym_4), add(sym_4, sym_3), sub(sym_1, sym_2)), add(sub(sym_1, sym_2), sym_2)), sub(lim(sym_2, sym_2, sin(sym_4)), lim(sin(sym_3), sin(sym_4), sym_1))))
# lim(sin(div(lim(sym_4, sym_3, sin(sym_3)), sin(sin(sym_3)))), sym_4, mul(lim(sin(lim(sym_1, sym_1, sym_3)), lim(sin(sym_3), sym_4, lim(sym_1, sym_1, sym_2)), mul(add(sym_3, sym_4), div(sym_2, sym_2))), mul(mul(lim(sym_1, sym_1, sym_4), add(sym_1, sym_4)), sym_3)))-----sin(lim(sin(div(lim(sym_4, sym_1, sym_3), lim(sym_3, sym_2, sym_2))), lim(sub(sin(sym_3), sub(sym_4, sym_2)), div(sym_2, lim(sym_3, sym_1, sym_1)), sin(sin(sym_2))), sym_2))
# sin(sin(add(sin(sym_3), sin(sym_3))))-----div(sub(lim(sin(sin(sym_3)), lim(sin(sym_2), sym_1, sym_2), lim(lim(sym_3, sym_2, sym_4), lim(sym_4, sym_2, sym_4), lim(sym_4, sym_2, sym_4))), sym_2), lim(sym_2, sin(lim(sym_1, add(sym_1, sym_2), sym_4)), sym_4))
# sym_2-----sin(sin(lim(sym_1, sym_4, div(sym_1, sym_1))))
# sin(div(lim(sym_1, sym_4, mul(sin(sym_3), sub(sym_1, sym_3))), sym_2))-----div(mul(sin(lim(div(sym_4, sym_1), lim(sym_4, sym_2, sym_4), sin(sym_2))), add(sub(sin(sym_1), sub(sym_3, sym_3)), sym_2)), sym_3)
# sym_3-----lim(sym_3, lim(lim(sin(sin(sym_2)), sym_3, lim(lim(sym_4, sym_4, sym_3), sub(sym_1, sym_2), add(sym_4, sym_4))), lim(add(sin(sym_1), sym_3), add(lim(sym_4, sym_1, sym_2), add(sym_2, sym_1)), sym_1), sin(sym_4)), sym_3)
# lim(sub(sin(sin(lim(sym_3, sym_4, sym_4))), lim(lim(sub(sym_4, sym_4), lim(sym_3, sym_2, sym_1), add(sym_3, sym_2)), div(sym_4, sin(sym_1)), sym_3)), div(sym_1, sym_1), lim(sin(sym_2), mul(sym_4, sym_3), sym_1))-----sub(sym_3, div(lim(lim(sin(sym_3), lim(sym_3, sym_4, sym_4), lim(sym_3, sym_3, sym_3)), sin(div(sym_3, sym_1)), div(lim(sym_1, sym_2, sym_3), add(sym_3, sym_1))), div(lim(sin(sym_1), sin(sym_2), sym_4), div(lim(sym_1, sym_2, sym_3), sin(sym_4)))))
# lim(lim(add(sym_3, sub(sym_1, mul(sym_3, sym_1))), add(lim(sin(sym_1), sym_4, sin(sym_1)), sym_2), sym_2), sym_1, lim(div(sin(lim(sym_2, sym_4, sym_2)), sym_2), sin(sym_4), sym_2))-----sym_3
# lim(sin(lim(lim(lim(sym_3, sym_2, sym_2), sym_3, sym_1), sin(lim(sym_2, sym_3, sym_4)), div(sin(sym_1), add(sym_2, sym_1)))), sym_2, sym_2)-----sin(sub(sym_4, lim(lim(sub(sym_4, sym_3), lim(sym_1, sym_3, sym_2), sin(sym_1)), lim(sym_1, sym_3, sym_1), sin(sym_3))))
# mul(add(sin(sin(sin(sym_2))), lim(mul(sin(sym_2), sin(sym_1)), add(sym_2, lim(sym_4, sym_1, sym_1)), sym_2)), sym_2)-----lim(sym_4, div(lim(sin(sym_3), mul(mul(sym_4, sym_3), sym_1), sin(lim(sym_2, sym_4, sym_3))), sym_3), sym_4)
# sym_3-----sym_1
# sym_2-----lim(sym_2, sin(sin(sin(sub(sym_4, sym_3)))), mul(lim(mul(sym_4, sym_4), lim(sym_3, lim(sym_1, sym_1, sym_3), sym_2), lim(div(sym_3, sym_3), lim(sym_4, sym_3, sym_1), mul(sym_3, sym_3))), sym_4))
# sin(sym_2)-----add(sin(lim(lim(add(sin(sym_2), div(sym_2, sym_3)), sin(lim(sym_3, sym_1, sym_2)), sin(sin(sym_2))), sym_3, sin(sin(sin(sym_1))))), sin(lim(sin(sin(sym_1)), lim(sin(sym_4), sin(sym_2), lim(sym_2, sym_4, sym_2)), sym_1)))
# sin(div(sin(sym_1), sym_4))-----sym_3
# sym_3-----lim(sym_3, sym_4, sym_1)
# sub(lim(sym_2, lim(sym_1, sin(lim(sym_1, sym_4, sym_2)), sym_3), sin(div(lim(sym_4, sym_1, sym_4), div(sym_1, sym_3)))), div(div(sin(add(sym_4, sym_4)), sub(sym_1, lim(sym_3, sym_4, sym_3))), sin(sym_1)))-----sym_4
# sub(add(sym_3, sin(div(sin(sym_2), sym_1))), sin(sin(sin(mul(sym_2, sym_3)))))-----sub(sub(lim(add(lim(sym_1, sym_3, sym_3), sym_3), sym_3, sym_4), sym_1), lim(sym_3, mul(sin(sym_1), sin(sin(sym_1))), lim(sub(sin(sym_3), sin(sym_4)), sym_2, sin(sub(sym_2, sym_4)))))
# lim(lim(sin(sin(sin(sym_4))), sub(lim(sym_2, sin(sym_3), lim(sym_4, sym_4, sym_2)), add(sub(sym_3, sym_2), lim(sym_2, sym_2, sym_2))), sin(div(sym_4, mul(sym_2, sym_4)))), sin(sym_3), sym_2)-----sin(mul(sym_4, lim(sym_2, sin(sym_1), sin(lim(sym_1, sym_2, sym_3)))))
# lim(sym_3, sym_1, lim(lim(div(sym_1, lim(sym_3, sym_3, sym_1)), lim(lim(sym_3, sym_3, sym_1), mul(sym_3, sym_3), add(sym_4, sym_1)), sin(sub(sym_3, sym_3))), sin(lim(sym_1, sym_3, sin(sym_2))), sym_3))-----mul(sin(lim(sin(sin(sym_1)), sym_4, sub(sin(sym_4), sub(sym_1, sym_1)))), sin(lim(sub(add(sym_4, sym_2), lim(sym_2, sym_4, sym_3)), lim(lim(sym_3, sym_2, sym_1), sub(sym_2, sym_2), add(sym_1, sym_1)), lim(sym_3, sym_4, div(sym_3, sym_2)))))
# sin(div(add(lim(sin(sym_1), lim(sym_3, sym_1, sym_2), lim(sym_4, sym_2, sym_4)), sin(sym_1)), mul(sym_1, sym_2)))-----lim(sin(sym_1), lim(sym_2, sym_4, lim(lim(mul(sym_1, sym_4), div(sym_2, sym_4), sym_2), lim(sym_3, sym_2, sin(sym_2)), mul(lim(sym_4, sym_2, sym_3), sin(sym_4)))), sym_2)
# div(lim(lim(sin(lim(sym_3, sym_1, sym_2)), sub(add(sym_3, sym_3), sym_3), sym_2), sin(sym_4), sym_2), sym_3)-----sym_3
# div(sym_1, sin(sin(sym_2)))-----sin(lim(mul(sin(sym_3), sin(sym_4)), sin(sub(sym_1, sym_2)), div(sin(sym_4), sym_4)))
# sym_2-----sin(sin(sym_1))
# lim(add(sin(lim(sym_4, div(sym_3, sym_4), div(sym_3, sym_1))), sym_4), sym_2, sym_3)-----sym_2
# mul(sym_4, div(lim(sub(sin(sym_3), sin(sym_1)), sin(div(sym_1, sym_1)), sym_2), add(div(mul(sym_1, sym_1), sym_3), sym_3)))-----sym_1
# sin(lim(mul(lim(sym_2, lim(sym_2, sym_4, sym_1), lim(sym_1, sym_2, sym_3)), sin(lim(sym_2, sym_4, sym_4))), add(lim(sym_1, sub(sym_4, sym_4), sin(sym_3)), sub(lim(sym_2, sym_2, sym_2), lim(sym_1, sym_4, sym_2))), sym_1))-----sin(lim(div(add(add(sym_2, sym_1), sub(sym_1, sym_2)), lim(sin(sym_3), lim(sym_4, sym_4, sym_2), lim(sym_2, sym_3, sym_4))), lim(sub(sub(sym_2, sym_2), div(sym_3, sym_3)), mul(sym_4, sin(sym_4)), sym_1), sub(lim(sym_2, sym_3, sin(sym_4)), sym_3)))
# sym_3-----sin(sym_3)
# sin(lim(mul(sin(sub(sym_1, sym_4)), sin(lim(sym_4, sym_3, sym_2))), mul(lim(sym_1, sym_3, lim(sym_4, sym_3, sym_1)), lim(sym_3, lim(sym_2, sym_2, sym_3), sin(sym_2))), div(sin(sym_2), sym_3)))-----lim(sym_3, lim(sym_1, sym_2, sym_1), sym_4)
# sym_2-----sym_2
# lim(sym_4, add(lim(add(lim(sym_3, sym_1, sym_1), lim(sym_2, sym_1, sym_2)), sin(sym_2), lim(lim(sym_3, sym_3, sym_2), sym_1, sym_3)), lim(mul(sym_2, sub(sym_1, sym_2)), lim(sym_3, lim(sym_3, sym_3, sym_2), sin(sym_1)), sin(lim(sym_3, sym_2, sym_3)))), sym_4)-----sin(mul(sub(sin(sin(sym_2)), sym_2), lim(sin(sin(sym_3)), lim(sym_1, lim(sym_1, sym_4, sym_3), div(sym_4, sym_2)), lim(mul(sym_2, sym_2), lim(sym_3, sym_3, sym_1), lim(sym_1, sym_2, sym_3)))))
# sym_3-----sin(sin(lim(lim(lim(sym_2, sym_4, sym_3), lim(sym_1, sym_4, sym_2), sub(sym_1, sym_4)), sym_2, sym_2)))
# add(sym_4, sym_3)-----lim(sin(sym_3), sin(lim(sin(sin(sym_4)), mul(sym_2, sym_2), div(sin(sym_4), sym_3))), sym_2)
# sin(mul(div(sym_2, mul(lim(sym_1, sym_2, sym_4), lim(sym_3, sym_2, sym_3))), sin(lim(sin(sym_2), sin(sym_1), lim(sym_3, sym_4, sym_4)))))-----mul(sin(lim(add(mul(sym_4, sym_4), sub(sym_3, sym_3)), sym_2, sin(div(sym_2, sym_3)))), sin(sin(sin(sin(sym_4)))))
# sin(sub(sub(sym_3, sym_1), sin(lim(sub(sym_4, sym_2), sym_1, div(sym_2, sym_1)))))-----sym_2
# sub(sym_1, mul(sin(sin(lim(sym_1, sym_1, sym_3))), sym_2))-----lim(sub(sin(sin(sin(sym_1))), sym_3), sym_1, lim(div(sym_3, sin(lim(sym_4, sym_2, sym_1))), add(sin(sin(sym_3)), lim(sym_2, sym_1, sym_4)), lim(sin(sym_2), sin(lim(sym_2, sym_2, sym_3)), add(add(sym_3, sym_1), sub(sym_1, sym_2)))))
# sym_2-----sin(lim(sub(lim(lim(sym_4, sym_3, sym_1), sym_2, mul(sym_1, sym_4)), sym_1), lim(lim(sym_1, sym_3, sin(sym_1)), lim(sym_2, sin(sym_4), add(sym_1, sym_1)), sin(lim(sym_4, sym_2, sym_2))), sin(sin(sym_4))))
# sub(add(sym_3, lim(sin(sin(sym_3)), sub(lim(sym_1, sym_2, sym_2), lim(sym_4, sym_3, sym_3)), sub(lim(sym_3, sym_2, sym_4), sym_4))), mul(sub(sym_2, lim(lim(sym_1, sym_4, sym_2), mul(sym_4, sym_2), sym_2)), lim(sym_4, div(sym_1, sym_4), sym_3)))-----sym_3
# sin(sin(mul(lim(add(sym_2, sym_1), add(sym_1, sym_1), lim(sym_1, sym_1, sym_2)), mul(mul(sym_2, sym_1), div(sym_1, sym_2)))))-----sin(sub(sym_3, sym_2))
# lim(sin(lim(sin(sub(sym_2, sym_3)), sin(lim(sym_1, sym_1, sym_3)), sin(lim(sym_1, sym_2, sym_2)))), lim(sym_4, sin(add(sub(sym_1, sym_1), lim(sym_3, sym_4, sym_2))), sym_3), sym_2)-----lim(lim(sym_4, sym_2, sin(sin(sin(sym_3)))), lim(add(lim(sym_2, sym_4, sub(sym_1, sym_2)), sin(sym_2)), sin(sin(sym_1)), sin(sub(lim(sym_2, sym_2, sym_4), sin(sym_1)))), sym_1)
# lim(sin(sin(sym_2)), sym_3, lim(sym_4, lim(mul(sin(sym_1), mul(sym_3, sym_1)), sym_2, sym_1), sin(sym_1)))-----sin(sin(lim(div(sym_2, sin(sym_4)), sub(lim(sym_4, sym_4, sym_4), sym_2), sub(sym_2, sin(sym_1)))))
# sin(lim(div(sym_4, sym_4), sym_3, lim(sin(lim(sub(lim(sym_1, sym_3, sym_1), sub(sym_2, sym_2)), sin(add(sym_4, sym_3)), sym_2)), mul(sin(lim(sym_3, sym_2, sym_2)), sub(sym_3, div(sym_1, sym_4))), sym_2)))-----lim(div(lim(sym_2, add(sym_3, sym_2), lim(sym_4, sym_3, sym_2)), sub(sym_3, mul(sym_3, sym_2))), sym_4, sin(add(sym_2, sym_3)))
# lim(sub(sin(sin(lim(sym_3, sym_4, sym_4))), lim(lim(sub(sym_4, sym_4), lim(sym_3, sym_2, sym_1), add(sym_3, sym_2)), div(sym_4, sin(sym_1)), sym_3)), div(sym_1, sym_1), lim(sin(sym_2), mul(sym_4, sym_3), sym_1))-----add(sym_3, sym_4)
# div(sin(mul(lim(sym_4, sym_3, sym_4), div(sym_2, sym_3))), lim(sub(sym_1, sub(sym_2, sym_4)), lim(sym_2, sym_1, sym_3), sym_1))-----sub(div(sub(sub(add(lim(sym_2, sym_4, sym_4), mul(sym_2, sym_1)), lim(sym_1, sin(sym_4), sin(sym_4))), lim(lim(lim(sym_3, sym_2, sym_2), lim(sym_4, sym_4, sym_4), sym_2), sym_3, sym_2)), add(sym_1, lim(sym_3, sin(sym_3), sym_3))), sym_3)
# sym_3-----sym_4
# lim(sub(sin(sin(lim(sym_3, sym_4, sym_4))), lim(lim(sub(sym_4, sym_4), lim(sym_3, sym_2, sym_1), add(sym_3, sym_2)), div(sym_4, sin(sym_1)), sym_3)), div(sym_1, sym_1), lim(sym_1, mul(sym_4, sym_3), div(sym_1, mul(sym_1, sym_2))))-----sin(sin(sym_2))
# sin(div(lim(lim(lim(sym_2, sym_1, sym_1), add(sym_3, sym_4), sym_1), lim(sin(sym_4), add(sym_4, sym_3), sub(sym_1, sym_2)), add(sub(sym_1, sym_2), sym_2)), sub(lim(sym_2, sym_2, sin(sym_4)), lim(sin(sym_3), sin(sym_4), sym_1))))-----sub(sym_4, add(sym_2, lim(sym_1, sym_4, mul(sin(sym_3), sub(sym_1, sym_3)))))
# div(sin(sub(sym_1, lim(sym_2, sym_2, sym_1))), sym_1)-----div(sin(sin(lim(sym_3, sin(sym_2), lim(sym_2, sym_4, sym_3)))), sin(sin(sin(sym_2))))
# sym_4-----lim(sym_4, lim(sym_1, sym_2, sin(sin(sym_2))), sin(sin(lim(sym_3, mul(sym_1, sym_3), lim(sym_2, sym_4, sym_2)))))
# lim(sin(div(sin(sym_2), sym_1)), sym_4, mul(lim(sin(lim(sym_1, sym_1, sym_3)), lim(sin(sym_3), sym_4, lim(sym_1, sym_1, sym_2)), mul(add(sym_3, sym_4), div(sym_2, sym_2))), mul(mul(lim(sym_1, sym_1, sym_4), add(sym_1, sym_4)), sym_3)))-----sub(add(sym_3, sin(div(lim(sym_4, sym_3, sin(sym_3)), sin(sin(sym_3))))), sin(sin(sin(mul(sym_2, sym_3)))))
# add(lim(sin(div(lim(sym_4, sym_1, sym_4), div(sym_1, sym_3))), sym_2, lim(sym_1, sin(lim(sym_1, sym_4, sym_2)), sym_3)), div(div(sin(add(sym_4, sym_4)), sub(sym_1, lim(sym_3, sym_4, sym_3))), sin(sym_1)))-----div(lim(div(sym_3, sin(lim(sym_4, sym_2, sym_1))), add(sin(sin(sym_3)), lim(sym_2, sym_1, sym_4)), lim(sin(sym_2), sin(lim(sym_2, sym_2, sym_3)), add(add(sym_3, sym_1), sub(sym_1, sym_2)))), sym_1)
# sin(sub(lim(lim(lim(sym_2, sym_4, sym_3), lim(sym_1, sym_4, sym_2), sub(sym_1, sym_4)), sym_2, sym_2), sym_3))-----sin(sin(sym_2))
# sym_3-----lim(sym_3, sym_4, sym_1)
# mul(sin(lim(lim(add(sin(sym_2), div(sym_2, sym_3)), sin(lim(sym_3, sym_1, sym_2)), sin(sin(sym_2))), sym_3, sin(sin(sin(sym_1))))), add(sin(sin(sin(sym_2))), lim(mul(sin(sym_2), sin(sym_1)), add(sym_2, lim(sym_4, sym_1, sym_1)), sym_2)))-----add(sym_2, sin(lim(sin(sin(sym_1)), lim(sin(sym_4), sin(sym_2), lim(sym_2, sym_4, sym_2)), sym_1)))
# lim(lim(add(sym_3, sub(sym_1, mul(sym_3, sym_1))), add(lim(sin(sym_1), sym_4, sin(sym_1)), sym_2), sym_2), sym_1, lim(div(sin(lim(sym_2, sym_4, sym_2)), sym_2), sin(sym_4), sym_2))-----sym_4
# lim(sin(div(lim(sym_4, sym_3, sin(sym_3)), sin(sin(sym_3)))), sym_4, mul(sin(div(lim(sym_4, sym_1, sym_3), lim(sym_3, sym_2, sym_2))), mul(mul(lim(sym_1, sym_1, sym_4), add(sym_1, sym_4)), sym_3)))-----sin(mul(div(sym_2, mul(lim(sym_1, sym_2, sym_4), lim(sym_3, sym_2, sym_3))), sin(lim(sin(sym_2), sin(sym_1), lim(sym_3, sym_4, sym_4)))))
# sin(mul(div(sym_2, mul(lim(sym_1, sym_2, sym_4), lim(sym_3, sym_2, sym_3))), sym_3))-----div(sin(lim(sin(sym_2), sin(sym_1), lim(sym_3, sym_4, sym_4))), mul(sin(lim(div(sym_4, sym_1), lim(sym_4, sym_2, sym_4), sin(sym_2))), add(sub(sin(sym_1), sub(sym_3, sym_3)), sym_2)))
# lim(lim(sin(sym_1), lim(lim(lim(sym_4, sym_4, sym_2), sub(sym_3, sym_1), sym_4), sym_4, sym_3), add(sin(sub(sym_4, sym_2)), sym_4)), sub(mul(sin(sym_3), sin(sym_4)), sin(sub(sym_1, sym_2))), sym_2)-----sin(lim(div(sin(sym_4), sym_4), lim(sym_4, sin(lim(sym_1, sym_1, sym_2)), sin(sym_4)), sym_2))
# lim(add(div(mul(sym_1, sym_1), sym_3), sym_3), sub(lim(sym_4, sin(lim(sym_1, sym_1, sym_2)), sin(sym_4)), sym_2), lim(sin(sym_1), lim(lim(lim(sym_4, sym_4, sym_2), sub(sym_3, sym_1), sym_4), sym_4, sym_3), add(sin(sub(sym_4, sym_2)), sym_4)))-----div(sym_4, div(lim(sub(sin(sym_3), sin(sym_1)), sin(div(sym_1, sym_1)), sym_2), sin(sin(sym_4))))
# mul(sym_4, div(lim(sub(sin(sym_3), sin(sym_1)), sin(div(sym_1, sym_1)), sym_2), add(div(mul(sym_1, sym_1), sym_3), sym_3)))-----lim(sym_4, add(lim(add(lim(sym_3, sym_1, sym_1), lim(sym_2, sym_1, sym_2)), sin(sym_2), lim(lim(sym_3, sym_3, sym_2), sym_1, sym_3)), lim(mul(sym_2, sub(sym_1, sym_2)), lim(sym_3, lim(sym_3, sym_3, sym_2), sin(sym_1)), sin(lim(sym_3, sym_2, sym_3)))), sym_4)
# sub(div(div(sin(add(sym_4, sym_4)), sub(sym_1, lim(sym_3, sym_4, sym_3))), sin(sym_1)), sin(lim(sym_1, sym_4, div(sym_1, sym_1))))-----sin(lim(sym_2, lim(sym_1, sin(lim(sym_1, sym_4, sym_2)), sym_3), sin(div(lim(sym_4, sym_1, sym_4), div(sym_1, sym_3)))))
# div(div(sin(div(div(mul(sym_1, sym_4), sub(sym_4, sym_1)), add(lim(sym_4, sym_1, sym_3), add(sym_2, sym_1)))), sin(add(lim(sym_1, sym_2, sym_3), mul(sym_1, sym_2)))), sin(sym_2))-----sin(sin(lim(lim(sym_3, sym_1, sym_3), sin(sym_2), sym_1)))
# sin(sub(sub(sym_3, sym_1), sin(lim(sub(sym_4, sym_2), sym_1, div(sym_2, sym_1)))))-----sin(div(add(lim(sin(sym_1), lim(sym_3, sym_1, sym_2), lim(sym_4, sym_2, sym_4)), sin(sym_1)), mul(sym_1, sym_2)))
# sin(lim(sym_3, mul(sym_1, sym_3), lim(sym_2, sym_4, sym_2)))-----sin(sin(div(sin(sym_1), sym_4)))
# add(lim(sym_2, sym_2, lim(sin(add(sym_3, sub(sym_4, sym_2))), sub(sin(mul(sym_3, sym_1)), sym_3), lim(sym_4, lim(mul(sym_3, sym_2), sin(sym_3), sin(sym_3)), sym_3))), sym_3)-----div(lim(lim(sin(lim(sym_3, sym_1, sym_2)), sub(add(sym_3, sym_3), sym_3), sym_2), sin(sym_4), sym_4), sin(lim(sym_2, sym_4, sym_3)))
# sin(sin(lim(sub(add(sym_4, sym_2), lim(sym_2, sym_4, sym_3)), lim(lim(sym_3, sym_2, sym_1), sub(sym_2, sym_2), add(sym_1, sym_1)), lim(sym_3, sym_4, div(sym_3, sym_2)))))-----lim(sin(lim(sin(sin(sym_1)), sym_4, sub(sin(sym_4), sub(sym_1, sym_1)))), sym_1, lim(mul(lim(sym_2, lim(sym_2, sym_4, sym_1), lim(sym_1, sym_2, sym_3)), sin(lim(sym_2, sym_4, sym_4))), add(lim(sym_1, sub(sym_4, sym_4), sin(sym_3)), sub(lim(sym_2, sym_2, sym_2), lim(sym_1, sym_4, sym_2))), sym_1))
# sym_2-----add(add(sym_3, sin(div(sin(sym_2), sym_1))), sin(sin(sin(mul(sym_2, sym_3)))))
# sub(sym_3, div(add(lim(sym_2, sym_4, sub(sym_1, sym_2)), sin(sym_2)), sin(sub(lim(sym_2, sym_2, sym_4), sin(sym_1)))))-----lim(lim(sym_4, sym_2, sin(sin(sin(sym_3)))), lim(sin(sin(sym_1)), div(lim(sin(sym_1), sin(sym_2), sym_4), div(lim(sym_1, sym_2, sym_3), sin(sym_4))), lim(lim(sin(sym_3), lim(sym_3, sym_4, sym_4), lim(sym_3, sym_3, sym_3)), sin(div(sym_3, sym_1)), div(lim(sym_1, sym_2, sym_3), add(sym_3, sym_1)))), sym_1)
# div(sym_1, sin(lim(mul(sym_2, sub(sym_1, sym_2)), lim(sym_3, lim(sym_3, sym_3, sym_2), sin(sym_1)), sin(lim(sym_3, sym_2, sym_3)))))-----lim(sym_4, add(lim(mul(sin(sym_3), sin(sym_4)), sin(sub(sym_1, sym_2)), div(sin(sym_4), sym_4)), lim(add(lim(sym_3, sym_1, sym_1), lim(sym_2, sym_1, sym_2)), sin(sym_2), lim(lim(sym_3, sym_3, sym_2), sym_1, sym_3))), sym_4)
# sin(sub(sym_2, lim(sin(sym_1), sin(sym_4), lim(sym_3, sym_2, sym_4))))-----add(add(sub(sym_4, lim(lim(sub(sym_4, sym_3), lim(sym_1, sym_3, sym_2), sin(sym_1)), lim(sym_1, sym_3, sym_1), sin(sym_3))), sin(sym_4)), sym_4)
# div(sub(mul(add(div(sym_2, sym_3), sub(sym_1, sym_2)), sub(sym_2, sym_1)), sym_2), lim(sym_2, sin(lim(sym_1, add(sym_1, sym_2), sym_4)), sym_4))-----div(sin(lim(sub(lim(sym_1, sym_3, sym_1), sub(sym_2, sym_2)), sin(add(sym_4, sym_3)), sym_2)), div(div(add(sym_4, lim(sym_3, sym_1, sym_4)), sym_2), lim(sin(sin(sym_3)), lim(sin(sym_2), sym_1, sym_2), lim(lim(sym_3, sym_2, sym_4), lim(sym_4, sym_2, sym_4), lim(sym_4, sym_2, sym_4)))))
# sin(div(sin(sym_1), sym_4))-----div(div(lim(lim(sym_4, sym_4, sym_4), sym_2, sym_4), lim(sub(sym_1, sym_1), div(sym_2, sym_1), lim(sym_4, sym_3, sym_1))), div(mul(add(div(sym_2, sym_3), sub(sym_1, sym_2)), sub(sym_2, sym_1)), div(add(sym_4, lim(sym_3, sym_1, sym_4)), sym_2)))
# lim(lim(sub(lim(sym_2, sin(sym_3), lim(sym_4, sym_4, sym_2)), add(sub(sym_3, sym_2), lim(sym_2, sym_2, sym_2))), sin(sin(sin(sym_4))), sym_4), sin(sym_3), sym_2)-----sym_1
# lim(add(sin(lim(sym_4, div(sym_3, sym_4), div(sym_3, sym_1))), sym_4), sym_2, sym_3)-----sym_2
# sin(lim(sym_2, sym_3, div(sin(add(sym_4, sym_3)), sin(mul(lim(sym_4, sym_3, sym_4), div(sym_2, sym_3))))))-----sub(sub(sym_1, lim(mul(sym_2, sym_2), sub(sym_3, sym_2), lim(sym_4, sym_4, sym_4))), sym_1)
# lim(sym_4, sub(sym_2, mul(lim(sym_4, lim(sym_4, sym_2, sym_3), sym_1), sym_4)), mul(sin(sym_2), lim(sym_4, lim(sin(sym_3), sym_3, sym_4), sub(lim(sym_1, sym_1, sym_2), sym_1))))-----add(sub(add(sym_4, mul(sin(sym_4), lim(sym_1, sym_4, sym_1))), lim(div(sym_3, lim(sym_1, sym_1, sym_2)), sym_1, sin(sin(sym_3)))), lim(sym_4, sin(add(sym_4, sym_3)), sym_4))
# sym_2-----lim(sym_4, div(lim(sin(sym_3), mul(mul(sym_4, sym_3), sym_1), sin(lim(sym_2, sym_4, sym_3))), sym_3), sym_4)
# add(sin(lim(sym_3, sym_4, sub(lim(sym_1, sym_3, sym_1), lim(sym_2, sym_2, sym_3)))), lim(sym_3, sub(lim(sym_4, lim(sym_3, sym_4, sym_1), sin(sym_2)), sin(sin(sym_2))), sym_2))-----sym_1
# sym_3-----div(lim(lim(sin(lim(sym_3, sym_1, sym_2)), sub(add(sym_3, sym_3), sym_3), sym_2), sin(sym_4), sym_2), sym_3)
# lim(lim(add(sym_3, sub(sym_1, mul(sym_3, sym_1))), add(lim(sin(sym_1), sym_4, sin(sym_1)), sym_2), sym_2), sym_1, lim(div(sin(lim(sym_2, sym_4, sym_2)), sym_2), sin(sym_4), sym_2))-----sin(sin(sym_1))
# sym_4-----sym_4
# sym_2-----sym_1
# lim(sub(sin(sin(sin(sym_1))), sym_3), sym_1, lim(div(sym_3, sin(lim(sym_4, sym_2, sym_1))), add(sin(sin(sym_3)), lim(sym_2, sym_1, sym_4)), lim(sin(sym_2), sin(lim(sym_2, sym_2, sym_3)), add(add(sym_3, sym_1), sub(sym_1, sym_2)))))-----sym_3
# mul(sin(lim(add(mul(sym_4, sym_4), sub(sym_3, sym_3)), sym_2, sin(div(sym_2, sym_3)))), sin(sin(sin(sin(sym_4)))))-----sym_1
# sym_2-----sin(div(lim(sym_1, sym_4, mul(sin(sym_3), sub(sym_1, sym_3))), sym_2))
# sym_2-----lim(add(sin(lim(sym_4, div(sym_3, sym_4), div(sym_3, sym_1))), sym_4), sym_2, sym_3)
# lim(sym_2, sin(sin(sin(sub(sym_4, sym_3)))), mul(lim(mul(sym_4, sym_4), lim(sym_3, lim(sym_1, sym_1, sym_3), sym_2), lim(div(sym_3, sym_3), lim(sym_4, sym_3, sym_1), mul(sym_3, sym_3))), sym_4))-----sym_1
# lim(sym_4, sub(div(lim(sym_2, add(sym_3, sym_2), lim(sym_4, sym_3, sym_2)), sub(sym_3, mul(sym_3, sym_2))), sym_2), mul(sym_4, lim(sym_4, lim(sin(sym_3), sym_3, sym_4), sub(lim(sym_1, sym_1, sym_2), sym_1))))-----sin(sin(sym_2))
# mul(sym_2, sym_2)-----lim(sym_4, lim(sym_1, sym_4, sin(sin(sym_2))), sin(sub(sin(sin(lim(sym_4, sym_1, sym_2))), sym_2)))
# sym_3-----sym_2
# lim(lim(sin(sin(sym_2)), lim(sym_4, div(sym_1, sym_1), sym_3), sym_3), sin(sym_2), add(mul(sym_4, lim(sym_2, sym_4, sym_4)), add(sym_2, lim(sym_2, sym_3, sym_1))))-----sin(sin(sym_1))
# div(sym_4, div(lim(sub(sin(sym_3), sin(sym_1)), sin(div(sym_1, sym_1)), sym_2), add(div(mul(sym_1, sym_1), sym_3), sym_3)))-----sym_4
# sin(mul(div(sym_2, mul(lim(sym_1, sym_2, sym_4), lim(sym_3, sym_2, sym_3))), sin(lim(sin(sym_2), sin(sym_1), lim(sym_3, sym_4, sym_4)))))-----sub(div(add(lim(sym_2, sym_4, sub(sym_1, sym_2)), sin(sym_2)), sin(sub(lim(sym_2, sym_2, sym_4), sin(sym_1)))), sym_3)
# add(sin(add(lim(sym_1, sym_2, sym_3), mul(sym_1, sym_2))), div(div(sin(add(sym_4, sym_4)), sub(sym_1, lim(sym_3, sym_4, sym_3))), sin(sym_1)))-----sub(div(lim(sin(div(lim(sym_4, sym_1, sym_4), div(sym_1, sym_3))), sym_2, lim(sym_1, sin(lim(sym_1, sym_4, sym_2)), sym_3)), sin(lim(lim(sym_3, sym_1, sym_3), sin(sym_2), sym_1))), sin(sym_2))
# lim(sym_4, lim(sin(sin(sym_2)), sym_1, lim(mul(sym_2, sub(sym_1, sym_2)), lim(sym_3, lim(sym_3, sym_3, sym_2), sin(sym_1)), sin(lim(sym_3, sym_2, sym_3)))), sin(sub(sin(sin(lim(sym_4, sym_1, sym_2))), sym_2)))-----lim(sym_4, add(lim(add(lim(sym_3, sym_1, sym_1), lim(sym_2, sym_1, sym_2)), sin(sym_2), lim(lim(sym_3, sym_3, sym_2), sym_1, sym_3)), sym_4), sym_4)
# sym_4-----mul(sym_2, sym_2)
# lim(lim(sin(sym_1), lim(lim(lim(sym_4, sym_4, sym_2), sub(sym_3, sym_1), sym_4), sym_4, sym_3), add(sin(sub(sym_4, sym_2)), sym_4)), sub(lim(sym_4, sin(lim(sym_1, sym_1, sym_2)), sin(sym_4)), sym_2), sin(sin(sym_4)))-----sym_4
# sym_4-----sub(div(sub(sub(add(lim(sym_2, sym_4, sym_4), mul(sym_2, sym_1)), lim(sym_1, sin(sym_4), sin(sym_4))), lim(lim(lim(sym_3, sym_2, sym_2), lim(sym_4, sym_4, sym_4), sym_2), sym_3, sym_2)), add(sym_1, lim(sym_3, sin(sym_3), sym_3))), sym_3)
# sym_4-----lim(sin(div(lim(sym_4, sym_3, sin(sym_3)), sin(sin(sym_3)))), sym_4, mul(sin(div(lim(sym_4, sym_1, sym_3), lim(sym_3, sym_2, sym_2))), mul(mul(lim(sym_1, sym_1, sym_4), add(sym_1, sym_4)), sym_3)))
# sin(mul(sin(div(lim(sym_4, sym_1, sym_3), lim(sym_3, sym_2, sym_2))), mul(mul(lim(sym_1, sym_1, sym_4), add(sym_1, sym_4)), sym_3)))-----lim(div(sin(sym_1), sym_4), sin(div(lim(sym_4, sym_3, sin(sym_3)), sin(sin(sym_3)))), sym_4)
# lim(sym_4, sub(sym_4, sym_2), mul(sin(sym_2), lim(sym_4, lim(sin(sym_3), sym_3, sym_4), sub(lim(sym_1, sym_1, sym_2), sym_1))))-----sin(sub(add(sym_4, mul(sin(sym_4), lim(sym_1, sym_4, sym_1))), lim(lim(sub(sym_4, sym_3), lim(sym_1, sym_3, sym_2), sin(sym_1)), lim(sym_1, sym_3, sym_1), sin(sym_3))))
# lim(div(sym_1, sym_1), sub(sin(sin(lim(sym_3, sym_4, sym_4))), lim(lim(sub(sym_4, sym_4), lim(sym_3, sym_2, sym_1), add(sym_3, sym_2)), div(sym_4, sin(sym_1)), sym_3)), sym_3)-----add(lim(sin(sym_2), mul(sym_4, sym_3), sym_1), sym_4)
# lim(add(div(mul(sym_1, sym_1), sym_3), sym_3), sym_4, sub(lim(sym_4, sin(lim(sym_1, sym_1, sym_2)), sin(sym_4)), sym_2))-----mul(lim(sin(sym_1), lim(lim(lim(sym_4, sym_4, sym_2), sub(sym_3, sym_1), sym_4), sym_4, sym_3), add(sin(sub(sym_4, sym_2)), sym_4)), div(lim(sub(sin(sym_3), sin(sym_1)), sin(div(sym_1, sym_1)), sym_2), add(div(mul(sym_1, sym_1), sym_3), sym_3)))
# sin(div(div(sin(sym_1), sym_4), sub(lim(sym_2, sym_2, sin(sym_4)), lim(sin(sym_3), sin(sym_4), sym_1))))-----sin(sin(lim(lim(lim(sym_2, sym_1, sym_1), add(sym_3, sym_4), sym_1), lim(sin(sym_4), add(sym_4, sym_3), sub(sym_1, sym_2)), add(sub(sym_1, sym_2), sym_2))))
# sub(sym_4, add(add(sub(sym_4, lim(lim(sub(sym_4, sym_3), lim(sym_1, sym_3, sym_2), sin(sym_1)), lim(sym_1, sym_3, sym_1), sin(sym_3))), sin(sym_4)), lim(sym_1, sym_4, mul(sin(sym_3), sub(sym_1, sym_3)))))-----add(sym_2, sym_4)
# sin(lim(lim(sin(sin(sym_3)), lim(sin(sym_2), sym_1, sym_2), lim(lim(sym_3, sym_2, sym_4), lim(sym_4, sym_2, sym_4), lim(sym_4, sym_2, sym_4))), lim(sym_4, sin(lim(sym_1, sym_1, sym_2)), sin(sym_4)), sym_2))-----add(sub(sym_2, div(sin(sym_4), sym_4)), lim(sym_2, sin(lim(sym_1, add(sym_1, sym_2), sym_4)), sym_4))
# lim(sin(div(lim(sym_4, sym_3, sin(sym_3)), sin(sin(sym_3)))), sym_4, mul(lim(sin(lim(sym_1, sym_1, sym_3)), lim(sin(sym_3), sym_4, lim(sym_1, sym_1, sym_2)), mul(add(sym_3, sym_4), div(sym_2, sym_2))), mul(mul(lim(sym_1, sym_1, sym_4), add(sym_1, sym_4)), sym_3)))-----sym_4
# div(div(sin(div(div(mul(sym_1, sym_4), sub(sym_4, sym_1)), add(lim(sym_4, sym_1, sym_3), add(sym_2, sym_1)))), sin(add(lim(sym_1, sym_2, sym_3), mul(sym_1, sym_2)))), sin(sym_2))-----sym_1
# lim(sym_4, div(sym_3, lim(sin(sym_3), mul(mul(sym_4, sym_3), sym_1), sin(lim(sym_2, sym_4, sym_3)))), sym_4)-----sin(div(mul(sym_1, sym_2), add(lim(sin(sym_1), lim(sym_3, sym_1, sym_2), lim(sym_4, sym_2, sym_4)), sin(sym_1))))
# lim(sym_4, add(lim(mul(sin(sym_3), sin(sym_4)), sin(sub(sym_1, sym_2)), div(sin(sym_4), sym_4)), lim(add(lim(sym_3, sym_1, sym_1), lim(sym_2, sym_1, sym_2)), sin(sym_2), lim(lim(sym_3, sym_3, sym_2), sym_1, sym_3))), sym_4)-----sym_4
# div(sin(lim(sin(sym_2), sin(sym_1), lim(sym_3, sym_4, sym_4))), mul(sin(sym_2), lim(sym_4, lim(sin(sym_3), sym_3, sym_4), sub(lim(sym_1, sym_1, sym_2), sym_1))))-----lim(sym_4, sub(div(lim(sym_2, add(sym_3, sym_2), lim(sym_4, sym_3, sym_2)), sub(sym_3, mul(sym_3, sym_2))), sym_2), mul(add(sub(sin(sym_1), sub(sym_3, sym_3)), sym_2), sin(lim(div(sym_4, sym_1), lim(sym_4, sym_2, sym_4), sin(sym_2)))))
# sin(mul(div(sym_2, mul(lim(sym_1, sym_2, sym_4), lim(sym_3, sym_2, sym_3))), sin(lim(sin(sym_2), sin(sym_1), lim(sym_3, sym_4, sym_4)))))-----sin(lim(sym_2, sym_3, div(sin(add(sym_4, sym_3)), sin(mul(lim(sym_4, sym_3, sym_4), div(sym_2, sym_3))))))
# add(sub(add(sym_4, mul(sin(sym_4), lim(sym_1, sym_4, sym_1))), lim(div(sym_3, lim(sym_1, sym_1, sym_2)), sym_1, sin(sin(sym_3)))), lim(sym_4, sin(add(sym_4, sym_3)), sym_4))-----sym_2
# lim(sym_3, lim(sin(sym_2), mul(sym_4, sym_3), sym_1), sub(sin(sin(lim(sym_3, sym_4, sym_4))), lim(lim(sub(sym_4, sym_4), lim(sym_3, sym_2, sym_1), add(sym_3, sym_2)), div(sym_4, sin(sym_1)), sym_3)))-----lim(div(sym_1, sym_1), sym_1, sym_4)
# lim(div(sym_1, sym_1), sin(sin(sin(sym_1))), sub(sin(sin(lim(sym_3, sym_4, sym_4))), lim(lim(sub(sym_4, sym_4), lim(sym_3, sym_2, sym_1), add(sym_3, sym_2)), div(sym_4, sin(sym_1)), sym_3)))-----lim(sub(sym_3, lim(sin(sym_2), mul(sym_4, sym_3), sym_1)), sym_1, lim(div(sym_3, sin(lim(sym_4, sym_2, sym_1))), add(sin(sin(sym_3)), lim(sym_2, sym_1, sym_4)), lim(sin(sym_2), sin(lim(sym_2, sym_2, sym_3)), add(add(sym_3, sym_1), sub(sym_1, sym_2)))))
# sub(sym_3, div(div(sin(add(sym_4, sym_4)), sub(sym_1, lim(sym_3, sym_4, sym_3))), sin(sym_1)))-----div(sin(lim(sym_1, sym_4, div(sym_1, sym_1))), lim(lim(sin(lim(sym_3, sym_1, sym_2)), sub(add(sym_3, sym_3), sym_3), sym_2), sin(sym_4), sym_2))
# sym_4-----sym_2
# div(sub(sym_2, lim(sym_2, sym_4, sym_3)), lim(sym_2, sin(lim(sym_1, add(sym_1, sym_2), sym_4)), sym_4))-----div(lim(lim(sin(lim(sym_3, sym_1, sym_2)), sub(add(sym_3, sym_3), sym_3), sym_2), sin(sym_4), sym_4), sin(mul(add(div(sym_2, sym_3), sub(sym_1, sym_2)), sub(sym_2, sym_1))))
# lim(sym_4, sub(div(lim(sym_2, add(sym_3, sym_2), lim(sym_4, sym_3, sym_2)), sub(sym_3, mul(sym_3, sym_2))), sym_2), mul(sym_4, sin(sin(mul(sym_2, sym_3)))))-----add(add(sym_3, sin(div(sin(sym_2), sym_1))), sin(lim(sym_4, lim(sin(sym_3), sym_3, sym_4), sub(lim(sym_1, sym_1, sym_2), sym_1))))
# lim(sin(sym_2), sym_4, mul(lim(sin(lim(sym_1, sym_1, sym_3)), lim(sin(sym_3), sym_4, lim(sym_1, sym_1, sym_2)), mul(add(sym_3, sym_4), div(sym_2, sym_2))), mul(mul(lim(sym_1, sym_1, sym_4), add(sym_1, sym_4)), sym_3)))-----sin(div(lim(sym_1, sym_4, mul(sin(sym_3), sub(sym_1, sym_3))), div(sin(sym_2), sym_1)))
# sin(div(add(lim(sin(sym_1), lim(sym_3, sym_1, sym_2), lim(sym_4, sym_2, sym_4)), sin(sym_1)), mul(sym_1, sym_2)))-----sym_4
# div(div(lim(lim(sin(sym_3), lim(sym_3, sym_4, sym_4), lim(sym_3, sym_3, sym_3)), sin(div(sym_3, sym_1)), div(lim(sym_1, sym_2, sym_3), add(sym_3, sym_1))), div(lim(sin(sym_1), sin(sym_2), sym_4), div(lim(sym_1, sym_2, sym_3), sin(sym_4)))), sym_3)-----sin(mul(sym_3, div(sym_2, mul(lim(sym_1, sym_2, sym_4), lim(sym_3, sym_2, sym_3)))))
# div(sym_1, sin(sym_1))-----sub(lim(sym_2, lim(sym_1, sin(lim(sym_1, sym_4, sym_2)), sym_3), sin(div(lim(sym_4, sym_1, sym_4), div(sym_1, sym_3)))), div(div(sin(add(sym_4, sym_4)), sub(sym_1, lim(sym_3, sym_4, sym_3))), lim(div(sym_3, sin(lim(sym_4, sym_2, sym_1))), add(sin(sin(sym_3)), lim(sym_2, sym_1, sym_4)), lim(sin(sym_2), sin(lim(sym_2, sym_2, sym_3)), add(add(sym_3, sym_1), sub(sym_1, sym_2))))))
# sym_4-----lim(lim(sin(sym_1), lim(lim(lim(sym_4, sym_4, sym_2), sub(sym_3, sym_1), sym_4), sym_4, sym_3), add(sin(sub(sym_4, sym_2)), sym_4)), sub(lim(sym_4, sin(lim(sym_1, sym_1, sym_2)), sin(sym_4)), sym_2), sym_2)
# div(div(lim(sub(sin(sym_3), sin(sym_1)), sin(div(sym_1, sym_1)), sym_2), sin(sin(sym_4))), lim(sym_3, sym_4, sub(lim(sym_1, sym_3, sym_1), lim(sym_2, sym_2, sym_3))))-----add(sin(sym_4), lim(sym_3, sub(lim(sym_4, lim(sym_3, sym_4, sym_1), sin(sym_2)), sin(sin(sym_2))), sym_2))
# div(sin(lim(add(mul(sym_4, sym_4), sub(sym_3, sym_3)), sym_2, sin(div(sym_2, sym_3)))), sin(sin(sin(sin(sym_4)))))-----sym_3
# sin(div(sin(sin(sin(sym_4))), lim(sym_1, sym_4, mul(sin(sym_3), sub(sym_1, sym_3)))))-----mul(sin(lim(add(mul(sym_4, sym_4), sub(sym_3, sym_3)), sym_2, sin(div(sym_2, sym_3)))), sin(sym_2))
# div(sin(sin(sub(sym_1, sym_2))), sin(sin(sin(sym_2))))-----lim(lim(sin(sym_1), lim(lim(lim(sym_4, sym_4, sym_2), sub(sym_3, sym_1), sym_4), sym_4, sym_3), add(sin(sub(sym_4, sym_2)), sym_4)), sub(mul(sin(sym_3), sin(sym_4)), sin(lim(sym_3, sin(sym_2), lim(sym_2, sym_4, sym_3)))), sym_2)
# mul(sym_1, sin(sin(sym_2)))-----sub(sub(lim(lim(lim(sym_3, sym_2, sym_2), lim(sym_4, sym_4, sym_4), sym_2), sym_3, sym_2), sub(add(lim(sym_2, sym_4, sym_4), mul(sym_2, sym_1)), lim(sym_1, sin(sym_4), sin(sym_4)))), add(sym_1, lim(sym_3, sin(sym_3), sym_3)))
# div(sin(mul(lim(sym_4, sym_3, sym_4), div(sym_2, sym_3))), sin(sym_1))-----sin(div(lim(sub(sym_1, sub(sym_2, sym_4)), lim(sym_2, sym_1, sym_3), sym_1), sym_4))
# add(sym_1, sin(lim(mul(sym_2, sub(sym_1, sym_2)), lim(sym_3, lim(sym_3, sym_3, sym_2), sin(sym_1)), sin(lim(sym_3, sym_2, sym_3)))))-----div(sym_4, sym_2)
# lim(sub(sin(sin(lim(sym_3, sym_4, sym_4))), lim(lim(sub(sym_4, sym_4), lim(sym_3, sym_2, sym_1), add(sym_3, sym_2)), div(sym_4, sin(sym_1)), sym_3)), div(sym_1, sym_4), lim(sym_1, mul(sym_4, sym_3), div(sym_1, mul(sym_1, sym_2))))-----lim(lim(sym_1, sin(sin(sin(sym_3))), sym_2), lim(sin(sin(sym_1)), div(lim(sin(sym_1), sin(sym_2), sym_4), div(lim(sym_1, sym_2, sym_3), sin(sym_4))), lim(lim(sin(sym_3), lim(sym_3, sym_4, sym_4), lim(sym_3, sym_3, sym_3)), sin(div(sym_3, sym_1)), div(lim(sym_1, sym_2, sym_3), add(sym_3, sym_1)))), sym_1)
# mul(sin(lim(lim(add(sin(sym_2), div(sym_2, sym_3)), sin(lim(sym_3, sym_1, sym_2)), sin(sin(sym_2))), sym_3, sin(sin(sin(sym_1))))), add(sin(sin(sin(sym_2))), lim(mul(sin(sym_2), sin(sym_1)), add(sym_2, lim(sym_4, sym_1, sym_1)), sym_2)))-----sym_4
# div(div(lim(lim(sym_4, sym_4, sym_4), sym_2, sym_4), lim(sub(sym_1, sym_1), div(sym_2, sym_1), lim(sym_4, sym_3, sym_1))), div(mul(add(div(sym_2, sym_3), sub(sym_1, sym_2)), sub(sym_2, sym_1)), div(add(sym_4, lim(sym_3, sym_1, sym_4)), sym_2)))-----div(add(sin(sin(sin(sym_2))), lim(mul(sin(sym_2), sin(sym_1)), add(sym_2, lim(sym_4, sym_1, sym_1)), sym_2)), sym_2)
# sin(div(add(sym_2, sym_3), sym_4))-----lim(div(lim(sym_2, add(sym_3, sym_2), lim(sym_4, sym_3, sym_2)), sub(sym_3, mul(sym_3, sym_2))), sym_4, sin(sin(sym_1)))
# sym_2-----sin(lim(sin(add(sym_2, sym_3)), div(lim(sym_2, add(sym_3, sym_2), lim(sym_4, sym_3, sym_2)), sub(sym_3, mul(sym_3, sym_2))), div(sym_4, sym_4)))
# div(sin(sub(sym_3, sym_2)), sym_1)-----sin(sub(sym_1, lim(sym_2, sym_2, sym_1)))
# sin(sin(lim(sub(sym_4, sym_2), sym_1, div(sym_2, sym_1))))-----sin(sub(sin(sym_1), sub(sym_3, sym_1)))
# div(sym_2, sym_2)-----add(lim(div(div(add(sym_4, lim(sym_3, sym_1, sym_4)), sym_2), lim(sin(sin(sym_3)), lim(sin(sym_2), sym_1, sym_2), lim(lim(sym_3, sym_2, sym_4), lim(sym_4, sym_2, sym_4), lim(sym_4, sym_2, sym_4)))), sin(lim(sub(lim(sym_1, sym_3, sym_1), sub(sym_2, sym_2)), sin(add(sym_4, sym_3)), sym_2)), lim(sin(add(sym_3, sub(sym_4, sym_2))), sub(sin(mul(sym_3, sym_1)), sym_3), lim(sym_4, lim(mul(sym_3, sym_2), sin(sym_3), sin(sym_3)), sym_3))), sym_3)
# sin(lim(sub(sym_1, lim(mul(sym_2, sym_2), sub(sym_3, sym_2), lim(sym_4, sym_4, sym_4))), sym_2, lim(div(sin(lim(sym_2, sym_4, sym_2)), sym_2), sin(sym_4), sym_2)))-----lim(sym_1, sym_1, lim(add(sym_3, sub(sym_1, mul(sym_3, sym_1))), add(lim(sin(sym_1), sym_4, sin(sym_1)), sym_2), sym_2))
# lim(sin(lim(sin(sin(sym_1)), sym_4, sub(sin(sym_4), sub(sym_1, sym_1)))), sym_1, lim(mul(lim(sym_2, lim(sym_2, sym_4, sym_1), lim(sym_1, sym_2, sym_3)), sin(lim(sym_2, sym_4, sym_4))), add(lim(sym_1, sub(sym_4, sym_4), sin(sym_3)), sub(lim(sym_2, sym_2, sym_2), lim(sym_1, sym_4, sym_2))), sym_1))-----sym_1
# sin(sym_2)-----div(div(add(lim(sin(sym_1), lim(sym_3, sym_1, sym_2), lim(sym_4, sym_2, sym_4)), sin(sym_1)), mul(sym_1, sym_2)), sym_4)
# sin(div(sym_4, mul(mul(lim(sym_1, sym_1, sym_4), add(sym_1, sym_4)), sym_3)))-----lim(sin(div(lim(sym_4, sym_3, sin(sym_3)), sin(sin(sym_3)))), sym_4, mul(lim(sin(lim(sym_1, sym_1, sym_3)), lim(sin(sym_3), sym_4, lim(sym_1, sym_1, sym_2)), mul(add(sym_3, sym_4), div(sym_2, sym_2))), add(sym_2, sym_3)))
# add(sin(sym_4), lim(sym_3, sub(lim(sym_4, lim(sym_3, sym_4, sym_1), sin(sym_2)), sin(sin(sym_2))), sym_2))-----sin(mul(div(sym_2, mul(lim(sym_1, sym_2, sym_4), lim(sym_3, sym_2, sym_3))), sin(lim(sin(sym_2), sin(sym_1), lim(sym_3, sym_4, sym_4)))))
# sym_4-----lim(sym_4, div(sym_3, lim(sin(sym_3), mul(mul(sym_4, sym_3), sym_1), sin(lim(sym_2, sym_4, sym_3)))), sym_4)
# mul(sin(sym_2), div(sin(div(div(mul(sym_1, sym_4), sub(sym_4, sym_1)), add(lim(sym_4, sym_1, sym_3), add(sym_2, sym_1)))), sin(add(lim(sym_1, sym_2, sym_3), mul(sym_1, sym_2)))))-----sin(sin(lim(sub(sym_4, sym_2), sym_1, div(sym_2, sym_1))))
# lim(sym_3, lim(sin(sin(sym_3)), lim(sin(sym_2), sym_1, sym_2), lim(lim(sym_3, sym_2, sym_4), lim(sym_4, sym_2, sym_4), lim(sym_4, sym_2, sym_4))), sub(sin(sin(lim(sym_3, sym_4, sym_4))), lim(lim(sub(sym_4, sym_4), lim(sym_3, sym_2, sym_1), add(sym_3, sym_2)), div(sym_4, sin(sym_1)), sym_3)))-----sub(sin(lim(sub(lim(sym_1, sym_3, sym_1), sub(sym_2, sym_2)), sin(add(sym_4, sym_3)), sym_2)), div(div(add(sym_4, lim(sym_3, sym_1, sym_4)), sym_2), div(sym_1, sym_1)))
# lim(sym_4, sub(sym_4, sym_2), mul(sin(sym_2), sym_4))-----add(div(lim(sub(sin(sym_3), sin(sym_1)), sin(div(sym_1, sym_1)), sym_2), sin(sin(sym_4))), lim(sym_4, lim(sin(sym_3), sym_3, sym_4), sub(lim(sym_1, sym_1, sym_2), sym_1)))
# div(lim(sym_1, mul(sym_4, sym_3), div(sym_1, mul(sym_1, sym_2))), sin(sin(sym_2)))-----lim(sym_1, div(sym_1, sym_1), sub(sin(sin(lim(sym_3, sym_4, sym_4))), lim(lim(sub(sym_4, sym_4), lim(sym_3, sym_2, sym_1), add(sym_3, sym_2)), div(sym_4, sin(sym_1)), sym_3)))
# sin(sub(lim(lim(sub(sym_4, sym_3), lim(sym_1, sym_3, sym_2), sin(sym_1)), lim(sym_1, sym_3, sym_1), sin(sym_3)), sin(sym_1)))-----lim(div(lim(sym_2, add(sym_3, sym_2), lim(sym_4, sym_3, sym_2)), sub(sym_3, mul(sym_3, sym_2))), sym_4, sin(add(sym_4, mul(sin(sym_4), lim(sym_1, sym_4, sym_1)))))
# lim(sin(div(lim(sym_4, sym_3, sin(sym_3)), sin(sin(sym_3)))), sym_4, mul(sin(mul(add(div(sym_2, sym_3), sub(sym_1, sym_2)), sub(sym_2, sym_1))), mul(mul(lim(sym_1, sym_1, sym_4), add(sym_1, sym_4)), sym_3)))-----div(lim(lim(sin(lim(sym_3, sym_1, sym_2)), sub(add(sym_3, sym_3), sym_3), sym_2), sin(sym_4), sym_4), sin(div(lim(sym_4, sym_1, sym_3), lim(sym_3, sym_2, sym_2))))
# lim(mul(lim(sin(lim(sym_1, sym_1, sym_3)), lim(sin(sym_3), sym_4, lim(sym_1, sym_1, sym_2)), mul(add(sym_3, sym_4), div(sym_2, sym_2))), mul(mul(lim(sym_1, sym_1, sym_4), add(sym_1, sym_4)), sym_3)), sin(div(lim(sym_4, sym_3, sin(sym_3)), sin(sin(sym_3)))), sin(lim(sym_1, sym_4, div(sym_1, sym_1))))-----mul(sym_4, div(div(sin(add(sym_4, sym_4)), sub(sym_1, lim(sym_3, sym_4, sym_3))), sin(sym_1)))
# lim(div(sym_1, sub(sym_3, sym_2)), sym_1, sym_4)-----div(sin(sym_1), sym_1)
# sub(sym_4, add(lim(sym_1, sym_4, mul(sin(sym_3), sub(sym_1, sym_3))), sym_2))-----div(div(lim(sub(sin(sym_3), sin(sym_1)), sin(div(sym_1, sym_1)), sym_2), add(div(mul(sym_1, sym_1), sym_3), sym_3)), sym_4)
# lim(sym_4, add(sym_1, sin(sub(sym_1, lim(sym_2, sym_2, sym_1)))), sym_4)-----sub(lim(add(lim(sym_3, sym_1, sym_1), lim(sym_2, sym_1, sym_2)), sin(sym_2), lim(lim(sym_3, sym_3, sym_2), sym_1, sym_3)), lim(mul(sin(sym_3), sin(sym_4)), sin(sub(sym_1, sym_2)), div(sin(sym_4), sym_4)))
# mul(sin(lim(add(mul(sym_4, sym_4), sub(sym_3, sym_3)), sym_2, sin(div(sym_2, sym_3)))), sin(sym_2))-----sub(sin(lim(lim(add(sin(sym_2), div(sym_2, sym_3)), sin(lim(sym_3, sym_1, sym_2)), sin(sin(sym_2))), sym_3, sin(sin(sin(sym_1))))), add(sin(sin(sin(sym_2))), lim(mul(sin(sym_2), sin(sym_1)), add(sym_2, lim(sym_4, sym_1, sym_1)), sym_2)))
# mul(sym_3, div(div(sin(add(sym_4, sym_4)), sub(sym_1, lim(sym_3, sym_4, sym_3))), sin(sym_1)))-----add(add(sin(div(sin(sym_2), sym_1)), lim(sin(div(lim(sym_4, sym_1, sym_4), div(sym_1, sym_3))), sym_2, lim(sym_1, sin(lim(sym_1, sym_4, sym_2)), sym_3))), sin(lim(sym_4, lim(sin(sym_3), sym_3, sym_4), sub(lim(sym_1, sym_1, sym_2), sym_1))))
# add(lim(sin(add(sym_2, sym_3)), div(lim(sym_2, add(sym_3, sym_2), lim(sym_4, sym_3, sym_2)), sub(sym_3, mul(sym_3, sym_2))), div(sym_4, sym_4)), sub(add(sym_4, mul(sin(sym_4), lim(sym_1, sym_4, sym_1))), lim(div(sym_3, lim(sym_1, sym_1, sym_2)), sym_1, sin(sin(sym_3)))))-----sin(lim(sym_4, sin(add(sym_4, sym_3)), sym_4))
# lim(sym_4, add(lim(sym_4, sin(lim(sym_1, sym_1, sym_2)), sin(sym_4)), div(sin(sym_4), sym_4)), sym_4)-----sin(lim(lim(add(lim(sym_3, sym_1, sym_1), lim(sym_2, sym_1, sym_2)), sin(sym_2), lim(lim(sym_3, sym_3, sym_2), sym_1, sym_3)), sym_4, sym_2))
# sin(sub(sub(lim(sym_4, sin(lim(sym_1, sym_1, sym_2)), sin(sym_4)), sym_2), add(div(mul(sym_1, sym_1), sym_3), sym_3)))-----lim(sym_1, lim(sym_2, sym_2, sym_1), sym_4)
# lim(mul(sin(sym_2), lim(sym_4, lim(sin(sym_3), sym_3, sym_4), sub(lim(sym_1, sym_1, sym_2), sym_1))), div(add(lim(sin(sym_1), lim(sym_3, sym_1, sym_2), lim(sym_4, sym_2, sym_4)), sin(sym_1)), mul(sym_1, sym_2)), sub(add(sym_4, mul(sin(sym_4), lim(sym_1, sym_4, sym_1))), sym_2))-----sin(sym_4)
# sub(div(add(lim(sym_2, sym_4, sub(sym_1, sym_2)), sin(sym_2)), sin(sub(lim(sym_2, sym_2, sym_4), sin(sym_1)))), mul(sym_4, sym_3))-----lim(sub(sin(sin(lim(sym_3, sym_4, sym_4))), lim(lim(sub(sym_4, sym_4), lim(sym_3, sym_2, sym_1), add(sym_3, sym_2)), div(sym_4, sin(sym_1)), sym_3)), div(sym_1, sym_1), lim(sin(sym_2), sym_3, sym_1))
# lim(lim(sin(sym_1), lim(lim(lim(sym_4, sym_4, sym_2), sub(sym_3, sym_1), sym_4), sym_4, sym_3), add(sin(sub(sym_4, sym_2)), sym_4)), sub(lim(sym_4, sin(lim(sym_1, sym_1, sym_2)), sin(sym_4)), sym_2), sin(sin(sym_4)))-----div(sin(lim(sym_1, sym_4, div(sym_1, sym_1))), lim(lim(sin(lim(sym_3, sym_1, sym_2)), sub(add(sym_3, sym_3), sym_3), sym_2), sin(sym_4), sym_2))
# sym_4-----div(sin(mul(lim(sym_4, sym_3, sym_4), div(sym_2, sym_3))), sin(sym_1))
# div(sym_3, div(lim(lim(sin(sym_3), lim(sym_3, sym_4, sym_4), lim(sym_3, sym_3, sym_3)), sin(div(sym_3, sym_1)), div(lim(sym_1, sym_2, sym_3), add(sym_3, sym_1))), sym_4))-----lim(div(sin(sym_1), sym_4), div(lim(sin(sym_1), sin(sym_2), sym_4), div(lim(sym_1, sym_2, sym_3), sin(sym_4))), sin(div(lim(sym_4, sym_3, sin(sym_3)), sin(sin(sym_3)))))
# lim(lim(sin(sym_2), mul(sym_4, sym_3), sym_1), sub(sin(sin(lim(sym_3, sym_4, sym_4))), lim(lim(sub(sym_4, sym_4), lim(sym_3, sym_2, sym_1), add(sym_3, sym_2)), div(sym_4, sin(sym_1)), sym_3)), add(lim(sym_1, sym_2, sym_3), mul(sym_1, sym_2)))-----add(sin(div(sym_1, sym_1)), div(div(sin(add(sym_4, sym_4)), sub(sym_1, lim(sym_3, sym_4, sym_3))), sin(sym_1)))
# lim(sym_4, div(lim(sin(sym_3), mul(mul(sym_4, sym_3), sym_1), sin(lim(sym_2, sym_4, sym_3))), sym_3), sym_4)-----sym_4
# lim(add(div(mul(sym_1, sym_1), sym_3), sym_3), sub(lim(sym_4, sin(lim(sym_1, sym_1, sym_2)), sin(sym_4)), sym_2), lim(sin(sym_1), lim(lim(lim(sym_4, sym_4, sym_2), sub(sym_3, sym_1), sym_4), sym_4, sym_3), add(sin(sub(sym_4, sym_2)), sym_4)))-----sym_4
# sin(lim(sym_4, sin(lim(sym_1, sym_1, sym_2)), sin(sym_4)))-----lim(lim(sin(sym_1), lim(lim(lim(sym_4, sym_4, sym_2), sub(sym_3, sym_1), sym_4), sym_4, sym_3), add(sin(sub(sym_4, sym_2)), sym_4)), sub(sym_2, mul(sym_3, div(sym_2, mul(lim(sym_1, sym_2, sym_4), lim(sym_3, sym_2, sym_3))))), sym_2)
# div(sin(lim(sin(sym_2), sin(sym_1), lim(sym_3, sym_4, sym_4))), sym_4)-----lim(mul(sin(sym_2), lim(sym_4, lim(sin(sym_3), sym_3, sym_4), sub(lim(sym_1, sym_1, sym_2), sym_1))), add(lim(mul(sin(sym_3), sin(sym_4)), sin(sub(sym_1, sym_2)), div(sin(sym_4), sym_4)), lim(add(lim(sym_3, sym_1, sym_1), lim(sym_2, sym_1, sym_2)), sin(sym_2), lim(lim(sym_3, sym_3, sym_2), sym_1, sym_3))), sym_4)
# sym_4-----lim(sym_4, lim(sin(sin(sym_2)), sym_1, lim(mul(sym_2, sub(sym_1, sym_2)), lim(sym_3, lim(sym_3, sym_3, sym_2), sin(sym_1)), sin(lim(sym_3, sym_2, sym_3)))), sin(sub(sin(sin(lim(sym_4, sym_1, sym_2))), sym_2)))
# add(sym_2, sym_4)-----sym_4
# sym_4-----div(div(sin(div(div(mul(sym_1, sym_4), sub(sym_4, sym_1)), add(lim(sym_4, sym_1, sym_3), add(sym_2, sym_1)))), sin(add(lim(sym_1, sym_2, sym_3), mul(sym_1, sym_2)))), sin(sym_2))
# lim(sin(sym_2), sym_4, mul(lim(sin(lim(sym_1, sym_1, sym_3)), lim(sin(sym_3), sym_4, lim(sym_1, sym_1, sym_2)), mul(add(sym_3, sym_4), div(sym_2, sym_2))), mul(mul(lim(sym_1, sym_1, sym_4), add(sym_1, sym_4)), sym_3)))-----sub(lim(sin(div(lim(sym_4, sym_1, sym_4), div(sym_1, sym_3))), div(sin(sym_2), sym_1), lim(sym_1, sin(lim(sym_1, sym_4, sym_2)), sym_3)), div(div(sin(add(sym_4, sym_4)), sub(sym_1, lim(sym_3, sym_4, sym_3))), lim(div(sym_3, sin(lim(sym_4, sym_2, sym_1))), add(sin(sin(sym_3)), lim(sym_2, sym_1, sym_4)), lim(sin(sym_2), sin(lim(sym_2, sym_2, sym_3)), add(add(sym_3, sym_1), sub(sym_1, sym_2))))))
# mul(sym_4, div(lim(sym_1, sym_4, sin(sin(sym_2))), sin(sub(sin(sin(lim(sym_4, sym_1, sym_2))), sym_2))))-----lim(lim(sub(sin(sym_3), sin(sym_1)), sin(div(sym_1, sym_1)), sym_2), sym_4, add(div(mul(sym_1, sym_1), sym_3), sym_3))
# sym_4-----sym_4
# div(lim(add(mul(sym_4, sym_4), sub(sym_3, sym_3)), sym_2, sin(div(sym_2, sym_3))), sym_3)-----add(sin(div(lim(lim(sin(sym_3), lim(sym_3, sym_4, sym_4), lim(sym_3, sym_3, sym_3)), sin(div(sym_3, sym_1)), div(lim(sym_1, sym_2, sym_3), add(sym_3, sym_1))), div(lim(sin(sym_1), sin(sym_2), sym_4), div(lim(sym_1, sym_2, sym_3), sin(sym_4))))), sin(sin(sin(sin(sym_4)))))
# lim(div(sym_1, sym_1), sin(sin(sin(sym_1))), sub(lim(lim(sub(sym_4, sym_4), lim(sym_3, sym_2, sym_1), add(sym_3, sym_2)), div(sym_4, sin(sym_1)), sym_3), sin(sin(lim(sym_3, sym_4, sym_4)))))-----sin(div(div(sin(sym_1), sym_4), sub(lim(sym_2, sym_2, sin(sym_4)), lim(sin(sym_3), sin(sym_4), sym_1))))
# add(lim(sin(sym_1), lim(lim(lim(sym_4, sym_4, sym_2), sub(sym_3, sym_1), sym_4), sym_4, sym_3), add(sin(sub(sym_4, sym_2)), sym_4)), sym_4)-----mul(div(lim(sub(sin(sym_3), sin(sym_1)), sin(div(sym_1, sym_1)), sym_2), add(div(mul(sym_1, sym_1), sym_3), sym_3)), lim(sin(sym_2), mul(sym_4, sym_3), sym_1))
# div(sin(lim(add(mul(sym_4, sym_4), sub(sym_3, sym_3)), sym_2, sin(div(sym_2, sym_3)))), sin(sin(sin(sin(sym_4)))))-----sin(mul(div(sym_2, mul(lim(sym_1, sym_2, sym_4), lim(sym_3, sym_2, sym_3))), sin(lim(sin(sym_2), sin(sym_1), lim(sym_3, sym_4, sym_4)))))
# lim(lim(lim(lim(lim(sym_4, sym_4, sym_2), sub(sym_3, sym_1), sym_4), sym_4, sym_3), sin(lim(sin(sym_2), sin(sym_1), lim(sym_3, sym_4, sym_4))), div(sym_2, mul(lim(sym_1, sym_2, sym_4), lim(sym_3, sym_2, sym_3)))), sub(lim(sym_4, sin(lim(sym_1, sym_1, sym_2)), sin(sym_4)), sym_2), sin(sin(sym_4)))-----sin(mul(sin(sym_1), add(sin(sub(sym_4, sym_2)), sym_4)))
# mul(sym_2, sym_2)-----sym_4
# sub(sym_3, div(mul(add(sub(sin(sym_1), sub(sym_3, sym_3)), sym_2), sin(lim(div(sym_4, sym_1), lim(sym_4, sym_2, sym_4), sin(sym_2)))), div(sin(add(sym_4, sym_4)), sub(sym_1, lim(sym_3, sym_4, sym_3)))))-----lim(sym_4, sin(sym_1), sub(div(lim(sym_2, add(sym_3, sym_2), lim(sym_4, sym_3, sym_2)), sub(sym_3, mul(sym_3, sym_2))), sym_2))
# sin(div(lim(sub(sym_1, sub(sym_2, sym_4)), lim(sym_2, sym_1, sym_3), sym_1), div(sub(sub(add(lim(sym_2, sym_4, sym_4), mul(sym_2, sym_1)), lim(sym_1, sin(sym_4), sin(sym_4))), lim(lim(lim(sym_3, sym_2, sym_2), lim(sym_4, sym_4, sym_4), sym_2), sym_3, sym_2)), add(sym_1, lim(sym_3, sin(sym_3), sym_3)))))-----sub(sym_3, sym_4)
# div(sub(sym_2, lim(sym_2, sym_4, sym_3)), div(mul(add(div(sym_2, sym_3), sub(sym_1, sym_2)), sub(sym_2, sym_1)), div(add(sym_4, lim(sym_3, sym_1, sym_4)), sym_2)))-----div(lim(sym_2, sin(lim(sym_1, add(sym_1, sym_2), sym_4)), sym_4), div(lim(lim(sym_4, sym_4, sym_4), sym_2, sym_4), lim(sub(sym_1, sym_1), div(sym_2, sym_1), lim(sym_4, sym_3, sym_1))))
# sin(div(sin(sin(sin(sym_4))), lim(sym_1, sym_4, mul(sin(sym_3), sub(sym_1, sym_3)))))-----sin(div(sym_4, sin(sym_1)))
# sin(div(lim(lim(lim(sym_2, sym_1, sym_1), add(sym_3, sym_4), sym_1), lim(sin(sym_4), add(sym_4, sym_3), sub(sym_1, sym_2)), add(sub(sym_1, sym_2), sym_2)), sub(lim(sym_2, sym_2, sin(sym_4)), lim(sin(sym_3), sin(sym_4), sym_1))))-----sin(mul(div(sym_2, mul(lim(sym_1, sym_2, sym_4), lim(sym_3, sym_2, sym_3))), sin(lim(sin(sym_2), sin(sym_1), lim(sym_3, sym_4, sym_4)))))
# sin(div(lim(sym_4, lim(sin(sym_3), sym_3, sym_4), sub(lim(sym_1, sym_1, sym_2), sym_1)), sin(sym_1)))-----lim(sym_4, sub(div(lim(sym_2, add(sym_3, sym_2), lim(sym_4, sym_3, sym_2)), sub(sym_3, mul(sym_3, sym_2))), sym_2), mul(sym_4, sym_4))
# div(sin(sin(sub(sym_1, sym_2))), sin(sin(sin(sym_2))))-----sub(div(lim(sin(div(lim(sym_4, sym_1, sym_4), div(sym_1, sym_3))), sym_2, lim(sym_1, sin(lim(sym_1, sym_4, sym_2)), sym_3)), sin(lim(lim(sym_3, sym_1, sym_3), sin(sym_2), sym_1))), sin(sym_2))
# mul(sub(mul(add(div(sym_2, sym_3), sub(sym_1, sym_2)), sub(sym_2, sym_1)), sym_2), lim(sym_2, sin(lim(sym_1, add(sym_1, sym_2), sym_4)), sym_4))-----sym_4
# ...
# lim(lim(add(sin(sin(sin(lim(sym_3, sym_4, sym_4)))), div(sin(sym_4), sym_4)), sin(sym_1), add(sin(sub(sym_4, sym_2)), sym_4)), div(lim(lim(sym_4, sym_4, sym_2), sub(sym_3, sym_1), sym_4), sub(sym_4, sym_2)), add(add(sym_3, sin(sub(sym_4, sym_2))), lim(sym_4, sin(lim(sym_1, sym_1, sym_2)), sin(sym_4))))-----add(sin(lim(sym_4, sin(lim(sym_1, sym_1, sym_2)), sin(sym_4))), sym_4)
# lim(sin(div(sym_1, sym_1)), sym_4, sym_4)-----lim(lim(add(sin(sin(sin(lim(sym_3, sym_4, sym_4)))), div(sin(sym_4), sym_4)), sin(sym_1), add(sin(sub(sym_4, sym_2)), sym_4)), add(sym_4, lim(lim(lim(sym_4, sym_4, sym_2), sub(sym_3, sym_1), sym_4), sym_4, sym_3)), div(lim(lim(sym_4, sym_4, sym_2), sub(sym_3, sym_1), sym_4), sub(add(sin(sub(sym_4, sym_2)), sym_4), sin(sym_1))))
# lim(sub(add(sin(sub(sym_4, sym_2)), sym_4), sin(sym_1)), add(add(sym_4, div(mul(sym_1, sym_1), sym_3)), lim(sym_4, sin(lim(sym_1, sym_1, sym_2)), sin(sym_4))), lim(sin(div(sym_1, sym_1)), sin(sym_1), add(sin(sub(sym_4, sym_2)), sym_4)))-----lim(sin(sin(add(lim(sym_4, sin(lim(sym_1, sym_1, sym_2)), sin(sym_4)), div(sin(sym_4), sym_4)))), add(sin(sin(sym_4)), sym_4), lim(sym_4, sin(div(sym_1, sym_1)), lim(sin(div(sym_1, sym_1)), add(sin(sub(sym_4, sym_2)), sym_4), sin(sym_1))))
# lim(sin(sin(add(lim(sym_4, sin(lim(sym_1, sym_1, sym_2)), sin(sym_4)), div(sin(sym_4), sym_4)))), sub(lim(lim(lim(lim(sym_4, sym_4, sym_2), sub(sym_3, sym_1), sym_4), sym_4, sym_3), add(div(sym_3, sym_3), sin(sub(sym_4, sym_2))), add(sin(sub(sym_4, sym_2)), sym_4)), sym_2), add(sin(sub(sym_4, sym_2)), sym_4))-----sin(lim(sym_4, sin(div(sym_1, sym_1)), lim(sin(div(sym_1, sym_1)), add(sin(sub(sym_4, sym_2)), sym_4), sin(sym_1))))
# div(sin(sin(div(sym_1, sym_1))), sin(div(mul(sym_1, sym_1), sym_3)))-----add(lim(sym_4, lim(add(sin(sub(sym_4, sym_2)), sym_4), div(lim(lim(sym_4, sym_4, sym_2), sub(sym_3, sym_1), sym_4), sub(sym_4, sym_2)), lim(sym_4, sin(lim(sym_1, sym_1, sym_2)), sin(sym_4))), div(lim(sym_4, sym_3, sin(sym_3)), sin(sin(sym_3)))), sin(lim(sym_4, sin(sym_4), mul(add(sin(sub(sym_4, sym_2)), sym_4), div(lim(sym_4, sym_3, sin(sym_3)), sin(sin(sym_3)))))))
# lim(lim(sin(sym_1), add(sin(sub(sym_4, sym_2)), sym_4), sub(add(lim(lim(sym_4, sym_4, sym_2), sub(sym_3, sym_1), sym_4), div(sin(sym_4), sym_4)), sym_4)), sub(lim(lim(lim(lim(sym_4, sym_4, sym_2), sub(sym_3, sym_1), sym_4), sym_4, sym_3), add(div(sym_3, sym_3), sin(sub(sym_4, sym_2))), add(sin(sub(sym_4, sym_2)), sym_4)), sym_2), sin(div(sym_1, sym_1)))-----lim(sym_4, lim(sin(div(sym_1, sym_1)), add(sym_4, sub(add(sin(sub(sym_4, sym_2)), sym_4), sin(sym_1))), add(sin(sub(sym_4, sym_2)), sym_4)), sin(div(sym_1, sym_1)))
# lim(add(sin(sin(sin(lim(sym_3, sym_4, sym_4)))), div(sin(sym_4), sym_4)), sin(add(sym_4, sym_3)), add(sin(sub(sym_4, sym_2)), sym_4))-----sin(add(sin(sub(sym_4, sym_2)), sym_4))
# lim(sin(add(sin(div(lim(sym_4, sym_3, sin(sym_3)), sin(sin(sym_3)))), lim(sym_4, sin(lim(sym_1, sym_1, sym_2)), sin(sym_4)))), sub(sin(add(lim(sym_4, sin(lim(sym_1, sym_1, sym_2)), sin(sym_4)), div(sin(sym_4), sym_4))), sym_2), add(sin(sym_4), sym_4))-----sin(add(add(sym_3, sin(sub(sym_4, sym_2))), sin(div(sym_1, sym_1))))
# lim(lim(sin(div(sym_1, sym_1)), sin(sym_1), add(sin(sub(sym_4, sym_2)), sym_4)), sin(lim(sin(div(sym_1, sym_1)), sin(sym_1), add(sin(sub(sym_4, sym_2)), sym_4))), sub(lim(lim(lim(lim(sym_4, sym_4, sym_2), sub(sym_3, sym_1), sym_4), sym_4, sym_3), add(div(sym_3, sym_3), sin(sub(sym_4, sym_2))), add(sin(sub(sym_4, sym_2)), sym_4)), sym_2))-----lim(sin(sym_4), div(sym_1, sym_1), sub(lim(lim(lim(lim(sym_4, sym_4, sym_2), sub(sym_3, sym_1), sym_4), sym_4, sym_3), add(div(sym_3, sym_3), sin(sub(sym_4, sym_2))), add(sin(sub(sym_4, sym_2)), sym_4)), sym_2))
# sin(lim(lim(lim(lim(sym_4, sym_4, sym_2), sub(sym_3, sym_1), sym_4), sym_4, sym_3), add(div(sym_3, sym_3), sin(sub(sym_4, sym_2))), add(sin(sub(sym_4, sym_2)), sym_4)))-----lim(sub(add(sym_4, lim(lim(lim(sym_4, sym_4, sym_2), sub(sym_3, sym_1), sym_4), sym_4, sym_3)), sym_2), sin(lim(sin(sym_1), sin(sym_2), sym_4)), lim(sin(div(sym_1, sym_1)), sin(sym_1), add(sin(sub(sym_4, sym_2)), sym_4)))
# sin(sym_4)-----add(sin(add(add(sym_3, sin(sub(sym_4, sym_2))), lim(sym_4, sin(lim(sym_1, sym_1, sym_2)), sin(sym_4)))), sin(sin(sin(lim(sym_3, sym_4, sym_4)))))
# sin(add(sub(sin(add(lim(sym_4, sin(lim(sym_1, sym_1, sym_2)), sin(sym_4)), div(sin(sym_4), sym_4))), sym_2), lim(sym_4, sin(lim(sym_1, sym_1, sym_2)), sin(sym_4))))-----lim(add(sin(sub(sym_4, sym_2)), sym_4), add(sym_4, sym_3), sin(add(sin(div(lim(sym_4, sym_3, sin(sym_3)), sin(sin(sym_3)))), lim(sym_4, sin(lim(sym_1, sym_1, sym_2)), sin(sym_4)))))
# lim(lim(sin(div(sym_1, sym_1)), sin(sym_1), add(sin(sub(sym_4, sym_2)), sym_4)), lim(sin(div(sym_1, sym_1)), add(sin(sub(sym_4, sym_2)), sym_4), add(sym_4, sub(add(sin(sub(sym_4, sym_2)), sym_4), sin(sym_1)))), sin(lim(sin(sym_1), add(sin(sub(sym_4, sym_2)), sym_4), sin(sub(sym_4, sym_2)))))-----sin(sym_4)
# lim(sub(div(lim(sym_4, sym_3, sin(sym_3)), sin(sin(sym_3))), sym_2), sin(sub(sym_4, sym_2)), sub(lim(sin(div(sym_1, sym_1)), add(sin(sub(sym_4, sym_2)), sym_4), sub(sym_4, sym_2)), sin(sym_1)))-----lim(sub(lim(sym_4, sin(lim(sym_1, sym_1, sym_2)), sin(sym_4)), sym_2), add(add(sym_4, sym_3), sym_4), add(lim(lim(sin(sym_3), lim(sym_3, sym_4, sym_4), lim(sym_3, sym_3, sym_3)), sin(div(sym_3, sym_1)), div(lim(sym_1, sym_2, sym_3), add(sym_3, sym_1))), div(lim(sym_4, sym_3, sin(sym_3)), sin(sin(sym_3)))))
# lim(lim(sin(div(sym_1, sym_1)), sin(sym_1), add(sin(sub(sym_4, sym_2)), sym_4)), sin(sym_4), sub(add(lim(lim(sym_4, sym_4, sym_2), sub(sym_3, sym_1), sym_4), div(sin(sym_4), sym_4)), sym_4))-----lim(sin(sym_1), add(div(div(lim(sym_1, sym_2, sym_3), sin(sym_4)), lim(sin(sym_1), sin(sym_2), sym_4)), sym_4), sin(div(lim(sym_4, sym_3, sin(sym_3)), sin(sin(sym_3)))))
# lim(sym_4, sin(div(sym_1, sym_1)), lim(add(sin(sub(sym_4, sym_2)), sym_4), lim(sin(div(sym_1, sym_1)), sin(sym_1), add(sin(sub(sym_4, sym_2)), sym_4)), add(sub(add(sin(sub(sym_4, sym_2)), sym_4), sin(sym_1)), sym_4)))-----lim(lim(sin(div(sym_1, sym_1)), sin(sym_1), add(sin(sub(sym_4, sym_2)), sym_4)), sin(add(sin(div(sym_1, sym_1)), sym_4)), sin(sym_1))
# add(sin(sym_4), add(sin(sin(sin(lim(sym_3, sym_4, sym_4)))), div(sin(sym_4), sym_4)))-----lim(sym_4, sin(div(sym_1, sym_1)), lim(add(sin(sub(sym_4, sym_2)), sym_4), sin(sym_1), sin(div(lim(sin(sym_3), mul(mul(sym_4, sym_3), sym_1), sin(lim(sym_2, sym_4, sym_3))), sym_3))))
# lim(lim(sin(div(sym_1, sym_1)), sin(sym_1), add(sin(sub(sym_4, sym_2)), sym_4)), sub(lim(sym_4, sin(lim(sym_1, sym_1, sym_2)), sin(sym_4)), sym_2), sin(div(sym_1, sym_1)))-----add(sin(sub(add(sin(sub(sym_4, sym_2)), sym_4), sym_4)), sin(sym_4))
# lim(add(sin(div(lim(sym_4, sym_3, sin(sym_3)), sin(sin(sym_3)))), sin(sin(sin(lim(sym_3, sym_4, sym_4))))), sin(add(sym_4, sym_3)), add(sin(div(sym_1, sym_1)), add(sin(sub(sym_4, sym_2)), sym_4)))-----sin(add(div(sin(sym_4), sym_4), lim(sym_4, sin(lim(sym_1, sym_1, sym_2)), sin(sym_4))))
# add(sub(add(lim(lim(lim(lim(sym_4, sym_4, sym_2), sub(sym_3, sym_1), sym_4), sym_4, sym_3), add(div(sym_3, sym_3), sin(sub(sym_4, sym_2))), add(sin(sub(sym_4, sym_2)), sym_4)), sym_2), sin(sym_2)), add(add(sin(sub(sym_4, sym_2)), sym_4), lim(sym_4, sin(lim(sym_1, sym_1, sym_2)), sin(sym_4))))-----lim(sub(div(lim(sin(sym_3), mul(mul(sym_4, sym_3), sym_1), sin(lim(sym_2, sym_4, sym_3))), sym_3), sym_2), add(add(sym_4, div(mul(sym_1, sym_1), sym_3)), lim(sym_4, sin(lim(sym_1, sym_1, sym_2)), sin(sym_4))), sin(sin(div(sym_1, sym_1))))
# lim(sub(sin(add(lim(sym_4, sin(lim(sym_1, sym_1, sym_2)), sin(sym_4)), div(sin(sym_4), sym_4))), sym_4), sin(sin(div(sym_1, sym_1))), lim(sym_4, sin(sym_1), add(sym_4, sin(sym_4))))-----add(add(sin(sub(sym_4, sym_2)), sym_4), sin(sym_2))
# sin(add(sin(add(lim(sym_4, sin(lim(sym_1, sym_1, sym_2)), sin(sym_4)), div(sin(sym_4), sym_4))), add(sin(sub(sym_4, sym_2)), sym_4)))-----lim(sin(sym_4), sub(div(lim(sym_4, sym_3, sin(sym_3)), sin(sin(sym_3))), sym_2), sub(sin(sym_1), sym_4))
# add(sin(sym_4), sym_4)-----lim(add(sym_4, sym_4), sym_4, sin(div(sym_1, sym_1)))
# lim(add(add(sym_4, div(mul(sym_1, sym_1), sym_3)), lim(sym_4, sin(lim(sym_1, sym_1, sym_2)), sin(sym_4))), sin(sin(lim(sin(div(sym_1, sym_1)), sin(sym_1), add(sin(sub(sym_4, sym_2)), sym_4)))), add(lim(lim(lim(lim(sym_4, sym_4, sym_2), sub(sym_3, sym_1), sym_4), sym_4, sym_3), add(div(sym_3, sym_3), sin(sub(sym_4, sym_2))), add(sin(sub(sym_4, sym_2)), sym_4)), sym_2))-----lim(sin(div(sym_1, sym_1)), sub(lim(sym_4, sin(lim(sym_1, sym_1, sym_2)), sin(sym_4)), sym_2), lim(add(sin(sub(sym_4, sym_2)), sym_4), sin(div(sym_1, sym_1)), sym_4))
# lim(sym_2, add(sin(lim(sym_4, sym_3, sin(sym_3))), sin(sub(sym_4, sym_2))), sin(add(lim(sym_4, sin(lim(sym_1, sym_1, sym_2)), sin(sym_4)), div(sin(sym_4), sym_4))))-----lim(sub(sin(sin(sym_1)), add(add(sym_4, div(mul(sym_1, sym_1), sym_3)), lim(sym_4, sin(lim(sym_1, sym_1, sym_2)), sin(sym_4)))), sin(sub(div(lim(sin(sym_3), mul(mul(sym_4, sym_3), sym_1), sin(lim(sym_2, sym_4, sym_3))), sym_3), sym_2)), lim(sin(sym_1), lim(lim(lim(sym_4, sym_4, sym_2), sub(sym_3, sym_1), sym_4), sym_4, sym_3), sym_4))
# lim(sub(lim(sym_4, sin(lim(sym_1, sym_1, sym_2)), sin(sym_4)), sym_2), add(sym_4, lim(sym_4, add(sin(sub(sym_4, sym_2)), sym_4), sym_4)), add(lim(lim(sin(sym_3), lim(sym_3, sym_4, sym_4), lim(sym_3, sym_3, sym_3)), sin(div(sym_3, sym_1)), div(lim(sym_1, sym_2, sym_3), add(sym_3, sym_1))), div(lim(sin(sym_1), sin(sym_2), sym_4), div(lim(sym_1, sym_2, sym_3), sin(sym_4)))))-----lim(add(sym_4, sym_3), sin(lim(sin(div(sym_1, sym_1)), sin(sym_1), add(sin(sub(sym_4, sym_2)), sym_4))), sub(lim(sym_4, sin(lim(sym_1, sym_1, sym_2)), sin(sym_4)), sym_2))
# lim(sin(sin(div(sym_1, sym_1))), sub(sym_4, sym_2), lim(sym_4, lim(lim(lim(sym_4, sym_4, sym_2), sub(sym_3, sym_1), sym_4), sym_4, sym_3), sin(sym_1)))-----div(sin(sin(div(lim(sin(sym_3), mul(mul(sym_4, sym_3), sym_1), sin(lim(sym_2, sym_4, sym_3))), sym_3))), sin(sym_4))
# add(sin(div(lim(sin(sym_3), mul(mul(sym_4, sym_3), sym_1), sin(lim(sym_2, sym_4, sym_3))), sym_3)), sin(add(sin(sym_4), sin(div(lim(sym_4, sym_3, sin(sym_3)), sin(sin(sym_3)))))))-----sin(sym_4)
# add(add(sym_4, add(sin(sub(sym_4, sym_2)), sym_4)), sin(div(lim(sin(sym_3), mul(mul(sym_4, sym_3), sym_1), sin(lim(sym_2, sym_4, sym_3))), sym_3)))-----sin(sin(sym_4))
# sin(add(sin(sub(sym_4, sym_2)), sin(div(sym_1, sym_1))))-----add(sin(sym_4), sin(add(sym_4, sin(sym_4))))
# lim(sin(sin(add(lim(sym_4, sin(lim(sym_1, sym_1, sym_2)), sin(sym_4)), div(sin(sym_4), sym_4)))), sin(div(sym_1, sym_1)), lim(sym_4, sin(sym_1), sub(add(sin(sub(sym_4, sym_2)), sym_4), sin(sym_1))))-----lim(lim(sym_4, sin(div(sym_1, sym_1)), lim(sin(div(sym_1, sym_1)), add(sin(sub(sym_4, sym_2)), sym_4), sin(sym_1))), sub(sin(add(lim(sym_4, sin(lim(sym_1, sym_1, sym_2)), sin(sym_4)), div(sin(sym_4), sym_4))), sym_2), add(sub(add(sin(sub(sym_4, sym_2)), sym_4), sin(sym_1)), sin(div(lim(sym_4, sym_3, sin(sym_3)), sin(sin(sym_3))))))
# lim(sin(div(sym_1, sym_1)), sin(sym_1), lim(add(sin(sub(sym_4, sym_2)), sym_4), sin(div(sym_1, sym_1)), sym_4))-----sin(lim(add(sin(sub(sym_4, sym_2)), sym_4), sub(lim(sym_4, sin(lim(sym_1, sym_1, sym_2)), sin(sym_4)), sym_2), sin(lim(sin(div(sym_1, sym_1)), sin(sym_1), add(sin(sub(sym_4, sym_2)), sym_4)))))
# sin(add(div(lim(sym_4, sym_3, sin(sym_3)), sin(sin(sym_3))), sub(add(sin(sub(sym_4, sym_2)), sym_4), sin(sym_1))))-----div(sin(div(lim(sin(sym_3), mul(mul(sym_4, sym_3), sym_1), sin(lim(sym_2, sym_4, sym_3))), sym_3)), sym_3)
# sin(lim(sin(sym_1), add(sin(sub(sym_4, sym_2)), sym_4), sin(div(sym_1, sym_1))))-----lim(sin(lim(sin(sym_1), add(sin(sub(sym_4, sym_2)), sym_4), sin(sub(sym_4, sym_2)))), lim(sym_4, add(sin(sub(sym_4, sym_2)), sym_4), sub(sym_4, sym_2)), sub(sym_4, sym_2))
# lim(sym_4, div(lim(sin(div(sym_1, sym_1)), sin(sym_1), add(sin(sub(sym_4, sym_2)), sym_4)), lim(lim(sin(sym_3), lim(sym_3, sym_4, sym_4), lim(sym_3, sym_3, sym_3)), sin(div(sym_3, sym_1)), div(lim(sym_1, sym_2, sym_3), add(sym_3, sym_1)))), div(sin(add(sym_3, sin(sub(sym_4, sym_2)))), lim(sym_4, sym_3, sin(sym_3))))-----lim(sin(sin(sym_3)), sym_4, sub(sub(sym_4, sym_2), sym_2))
# lim(add(lim(lim(sin(sym_3), lim(sym_3, sym_4, sym_4), lim(sym_3, sym_3, sym_3)), sin(div(sym_3, sym_1)), div(lim(sym_1, sym_2, sym_3), add(sym_3, sym_1))), div(lim(sin(sym_1), sin(sym_2), sym_4), div(lim(sym_1, sym_2, sym_3), sin(sym_4)))), sin(sym_1), add(sym_4, add(sym_4, sym_3)))-----lim(add(sin(lim(sym_4, sym_3, sin(sym_3))), sin(sub(sym_4, sym_2))), sin(sub(lim(sym_4, sin(lim(sym_1, sym_1, sym_2)), sin(sym_4)), sym_2)), sub(lim(sym_4, sin(lim(sym_1, sym_1, sym_2)), sin(sym_4)), sym_2))
# ['sub(sym_4, add(lim(lim(lim(sym_2, sym_1, sym_1), add(sym_3, sym_4), sym_1), lim(sin(sym_4), add(sym_4, sym_3), sub(sym_1, sym_2)), add(sub(sym_1, sym_2), sym_2)), sub(lim(sym_2, sym_2, sin(sym_4)), lim(sin(sym_3), sin(sym_4), sym_1))))', 'add(add(sub(sym_4, lim(lim(sub(sym_4, sym_3), lim(sym_1, sym_3, sym_2), sin(sym_1)), lim(sym_1, sym_3, sym_1), sin(sym_3))), sin(sym_4)), sym_4)', 'add(sub(add(sym_4, mul(sin(sym_4), lim(sym_1, sym_4, sym_1))), lim(div(sym_3, lim(sym_1, sym_1, sym_2)), sym_1, sin(sin(sym_3)))), lim(sym_4, sin(add(sym_4, sym_3)), sym_4))', 'add(sym_4, div(lim(sub(sin(sym_3), sin(sym_1)), sin(div(sym_1, sym_1)), sym_2), add(div(mul(sym_1, sym_1), sym_3), sym_3)))', 'add(div(lim(sub(sin(sym_3), sin(sym_1)), sin(div(sym_1, sym_1)), sym_2), add(div(mul(sym_1, sym_1), sym_3), sym_3)), sym_4)', 'add(sin(sym_4), lim(sym_3, lim(lim(lim(sym_4, sym_4, sym_2), sub(sym_3, sym_1), sym_4), sym_4, sym_3), add(sin(sub(sym_4, sym_2)), sym_4)))', 'add(lim(sym_3, lim(lim(lim(sym_4, sym_4, sym_2), sub(sym_3, sym_1), sym_4), sym_4, sym_3), add(sin(sub(sym_4, sym_2)), sym_4)), lim(sub(sym_1, sym_2), sym_4, lim(lim(sym_4, sym_4, sym_2), sub(sym_3, sym_1), sym_4)))', 'add(sin(sym_4), lim(sym_3, add(sin(sub(sym_4, sym_2)), sym_4), sym_4))', 'add(sin(add(lim(sym_4, sin(lim(sym_1, sym_1, sym_2)), sin(sym_4)), div(sin(sym_4), sym_4))), lim(sym_3, add(sin(sub(sym_4, sym_2)), sym_4), sym_4))', 'sin(add(add(sin(sub(sym_4, sym_2)), sym_4), sin(div(sym_1, sym_1))))', 'add(add(sin(sub(sym_4, sym_2)), lim(sym_4, sin(add(sym_4, sym_3)), sym_4)), sym_4)', 'add(sym_4, add(sin(sub(sym_4, sym_2)), sym_4))', 'add(sym_4, lim(sym_4, sin(lim(sym_1, sym_1, sym_2)), sin(sym_4)))', 'lim(sub(lim(lim(lim(lim(sym_4, sym_4, sym_2), sub(sym_3, sym_1), sym_4), sym_4, sym_3), add(div(sym_3, sym_3), sin(sub(sym_4, sym_2))), add(sin(sub(sym_4, sym_2)), sym_4)), sym_2), sin(sym_4), lim(sin(div(sym_1, sym_1)), sin(sym_1), add(sin(sub(sym_4, sym_2)), sym_4)))', 'lim(add(sub(sym_4, sym_2), div(sin(sym_4), sym_4)), mul(add(sin(sub(sym_4, sym_2)), sym_4), div(lim(sym_4, sym_3, sin(sym_3)), sin(sin(sym_3)))), sym_4)', 'div(sin(div(lim(sin(sym_3), mul(mul(sym_4, sym_3), sym_1), sin(lim(sym_2, sym_4, sym_3))), sym_3)), sin(sin(sub(sym_4, sym_2))))', 'add(sym_4, sym_4)', 'lim(lim(sin(div(sym_1, sym_1)), sin(sym_1), add(sin(sub(sym_4, sym_2)), sym_4)), sub(lim(lim(lim(lim(sym_4, sym_4, sym_2), sub(sym_3, sym_1), sym_4), sym_4, sym_3), add(div(sym_3, sym_3), sin(sub(sym_4, sym_2))), add(sin(sub(sym_4, sym_2)), sym_4)), sym_2), sin(div(sym_1, sym_1)))', 'lim(sub(lim(sym_4, sin(lim(sym_1, sym_1, sym_2)), sin(sym_4)), sym_2), sin(lim(sin(div(sym_1, sym_1)), sin(sym_1), add(sin(sub(sym_4, sym_2)), sym_4))), lim(add(sin(sub(sym_4, sym_2)), sym_4), sin(div(sym_1, sym_1)), sym_4))', 'lim(sub(lim(sym_4, sin(lim(sym_1, sym_1, sym_2)), sin(sym_4)), sym_2), sin(lim(sin(div(sym_1, sym_1)), sin(sym_1), add(sin(sub(sym_4, sym_2)), sym_4))), lim(add(sin(sub(sym_4, sym_2)), sym_4), sym_4, sin(div(sym_1, sym_1))))']
# [24.8, 25.0, 25.0, 25.0, 25.0, 25.0, 25.0, 25.0, 25.0, 25.0, 25.0, 25.0, 25.0, 25.0, 25.0, 25.0, 25.0, 25.0, 25.0, 25.0]

# %%
print(str(best_solutions[-1]))
print(str(best_scores[-1]))
# Out:
# lim(sym_1, lim(sym_1, lim(sin(sub(sym_3, sym_4)), sym_1, sub(lim(sym_1, sym_1, sym_2), sym_1)), sym_4), lim(sym_1, sin(sym_1), lim(sym_4, sym_2, sym_2)))
# -8.0

# %%
print(str(best_solutions[-1]))
print(str(best_scores[-1]))
# Out:
# lim(sub(lim(sym_4, sin(lim(sym_1, sym_1, sym_2)), sin(sym_4)), sym_2), sin(lim(sin(div(sym_1, sym_1)), sin(sym_1), add(sin(sub(sym_4, sym_2)), sym_4))), lim(add(sin(sub(sym_4, sym_2)), sym_4), sym_4, sin(div(sym_1, sym_1))))
# 25.0

# %%
import gymnasium as gym
sin = math.sin
step_count = 4000
best_program = lambda sym_1, sym_2, sym_3, sym_4: lim(sym_1, lim(sym_1, lim(math.sin(sub(sym_3, sym_4)), sym_1, sub(lim(sym_1, sym_1, sym_2), sym_1)), sym_4), lim(sym_1, sin(sym_1), lim(sym_4, sym_2, sym_2)))


visible = True
if visible:
    env = gym.make("CartPole-v1", render_mode="human")
else:
    env = gym.make("CartPole-v1")
env.reset()


step_result = env.reset()
score = 0.
# hard coded - an episode consists of 10 evaluations.
for i in range(0, step_count):
    if (len(step_result)>=5 and (step_result[2] or step_result[3])):
        
        break
    step_result = env.step(cartpole_wrapper(best_program(*step_result[0]))) #type: ignore
    print (step_result)
    if (step_result[4]):
        
        break
    score = score + step_result[1] #type: ignore

print (score)
# print(score)
env.close()
# Out:
# (array([-0.04889956, -0.19121426,  0.03136238,  0.34358838], dtype=float32), 1.0, False, False, {})
# (array([-0.05272384, -0.386768  ,  0.03823415,  0.64599377], dtype=float32), 1.0, False, False, {})
# (array([-0.0604592 , -0.5824013 ,  0.05115402,  0.95046735], dtype=float32), 1.0, False, False, {})
# (array([-0.07210723, -0.7781731 ,  0.07016337,  1.2587736 ], dtype=float32), 1.0, False, False, {})
# (array([-0.08767069, -0.9741191 ,  0.09533884,  1.5725806 ], dtype=float32), 1.0, False, False, {})
# (array([-0.10715307, -1.1702404 ,  0.12679045,  1.8934138 ], dtype=float32), 1.0, False, False, {})
# (array([-0.13055788, -1.3664894 ,  0.16465873,  2.222601  ], dtype=float32), 1.0, False, False, {})
# (array([-0.15788767, -1.5627545 ,  0.20911075,  2.5612078 ], dtype=float32), 1.0, False, False, {})
# (array([-0.18914276, -1.7588419 ,  0.2603349 ,  2.9099631 ], dtype=float32), 1.0, True, False, {})
# 9.0
